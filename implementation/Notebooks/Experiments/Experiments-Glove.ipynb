# %% [markdown]
# # Default Setup

# %%
# Dataloading Stuff
from google.colab import drive
from sys import path
import os

# Standard Stuff
# !pip3 install numpy sklearn iterative-stratification pandas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Glove Stuff
from scipy import spatial
from sklearn.manifold import TSNE

# Use SS3 Repo
# !rm -rf pyss3
# !git clone https://github.com/sergioburdisso/pyss3.git

from pyss3.pyss3.__init__ import SS3
from pyss3.pyss3.util import Dataset, Evaluation, span

# Mount Google Drive
drive.mount('/content/drive', force_remount=True)
path_root = '/content/drive/My Drive/NLP Lab'
path.append(path_root)
data_root = '/data'
multi_label_dir = '/SB1_Train_Multilabel'
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (1.18.4)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: iterative-stratification in /usr/local/lib/python3.6/dist-packages (0.1.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (1.0.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from iterative-stratification) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (0.15.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)
# Cloning into 'pyss3'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 1895 (delta 55), reused 73 (delta 37), pack-reused 1793
# Receiving objects: 100% (1895/1895), 49.06 MiB | 32.37 MiB/s, done.
# Resolving deltas: 100% (1225/1225), done.
# Mounted at /content/drive

# %% [markdown]
# ## Load Data

# %%
attribute = True
if attribute:
  text, labels = Dataset.load_from_files_multilabel(path_root + data_root + multi_label_dir + '/attribute-text.txt', path_root + data_root + multi_label_dir + '/attribute-labels.txt', sep_label=';')
  X_train, X_val, y_train, y_val = train_test_split(text, labels, test_size=0.3)
else:
  text, labels = Dataset.load_from_files_multilabel(path_root + data_root + multi_label_dir + '/entity-text.txt', path_root + data_root + multi_label_dir + '/entity-labels.txt', sep_label=';')
  X_train, X_val, y_train, y_val = train_test_split(text, labels, test_size=0.3)
# Out:
# 100%|██████████| 3748/3748 [00:00<00:00, 662519.02it/s]

# %% [markdown]
# ## Load Glove Embeddings

# %%
# https://gist.github.com/EvolvedSquid/03b002ae0a623c2d2ecab378255b7aaa#file-get_closest_embeddings-py
embeddings_dict = {}
with open("/content/drive/My Drive/NLP Lab/data/glove.840B.300d.txt", 'r', encoding="utf-8") as files:
  for line in files:
    values = line.split()
    word = values[0]
    try:
      vector = np.asarray(values[1:], "float32")
      if len(vector) == 300: ## Unfortunately there are some entries not correct
        embeddings_dict[word] = vector
    except:
      print("Failed:", word, values[1])
# Out:
# Failed: . .
# Failed: at name@domain.com
# Failed: . .
# Failed: to name@domain.com
# Failed: . .
# Failed: . .
# Failed: email name@domain.com
# Failed: or name@domain.com
# Failed: contact name@domain.com
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-4ea42a59053f> in <module>()
#       3 with open("/content/drive/My Drive/NLP Lab/data/glove.840B.300d.txt", 'r', encoding="utf-8") as files:
#       4   for line in files:
# ----> 5     values = line.split()
#       6     word = values[0]
#       7     try:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Get NLTK Stuff ready

# %%
# !pip3 install nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk import download

download('stopwords')
download('punkt')

stop_words = set(stopwords.words('english'))
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk) (1.12.0)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Tokenize and Filter Stopwords

# %%
def tokenize_samples(samples):
  return list(map(word_tokenize, samples))

def filter_stop_words(token_samples):
  return list(map(lambda x: [w for w in x if w not in stop_words], token_samples))

X_train_tok = tokenize_samples(X_train)
X_train_filtered = filter_stop_words(X_train_tok)

token_test = tokenize_samples(["This is a sample sentence, showing off the stop words filtration."])
filter_test = filter_stop_words(token_test)
filter_test
# Out:
# [['This',
#   'sample',
#   'sentence',
#   ',',
#   'showing',
#   'stop',
#   'words',
#   'filtration',
#   '.']]

# %% [markdown]
# ## Enhance with words found by glove embedding

# %%
def find_closest_embeddings_word(embedding, num_words):
  return sorted(embeddings_dict.keys(), key=lambda word: spatial.distance.euclidean(embeddings_dict[word], embedding))[1:num_words+1]

def enhance_with_glove_stupid(filtered_words, num_words):
  for sample in filtered_words:
    for word in sample:
      closest = find_closest_embeddings_word(embeddings_dict[word], num_words)
    return word, closest


def enhance_with_glove(filtered_words, num_words):
  enhanced_words = []
  for sample in filtered_words:
    print("Before:", sample)
    closest_words = [find_closest_embeddings_word(embeddings_dict[word], num_words) for word in sample]
    for closest in closest_words:
      sample.extend(closest)
    enhanced_words.append(sample)
    print("After:", sample)
  return enhanced_words

#enhance_with_glove([['This']], 2)

# %% [markdown]
# ## Definitely a nice try, but runtime complexity is definitely to high
# So lets try out something different. We will first use a smaller glove embedding.

# %%
embeddings_dict_small = {}
with open("/content/drive/My Drive/NLP Lab/data/glove.6B.50d.txt", 'r', encoding="utf-8") as files:
  for line in files:
    values = line.split()
    word = values[0]
    try:
      vector = np.asarray(values[1:], "float32")
      if len(vector) == 50: ## Unfortunately there are some entries not correct
        embeddings_dict_small[word] = vector
    except:
      print("Failed:", word, values[1])

# %%
def find_closest_embeddings_word_small(embedding, num_words):
  print("Embedding")
  return sorted(embeddings_dict_small.keys(), key=lambda word: spatial.distance.euclidean(embeddings_dict_small[word], embedding))[1:num_words+1]

def enhance_with_glove_small(filtered_words, num_words):
  enhanced_words = []
  for sample in filtered_words:
    print("Before:", sample)
    closest_words = [find_closest_embeddings_word_small(embeddings_dict_small[word], num_words) for word in sample]
    for closest in closest_words:
      sample.extend(closest)
    enhanced_words.append(sample)
    print("After:", sample)
  return enhanced_words

enhance_with_glove_small([['Soccer']], 2)
# Out:
# Before: ['Soccer']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-fa6b56fe2e03> in <module>()
#      14   return enhanced_words
#      15
# ---> 16 enhance_with_glove_small([['Soccer']], 2)
#
# <ipython-input-21-fa6b56fe2e03> in enhance_with_glove_small(filtered_words, num_words)
#       7   for sample in filtered_words:
#       8     print("Before:", sample)
# ----> 9     closest_words = [find_closest_embeddings_word_small(embeddings_dict_small[word], num_words) for word in sample]
#      10     for closest in closest_words:
#      11       sample.extend(closest)
#
# <ipython-input-21-fa6b56fe2e03> in <listcomp>(.0)
#       7   for sample in filtered_words:
#       8     print("Before:", sample)
# ----> 9     closest_words = [find_closest_embeddings_word_small(embeddings_dict_small[word], num_words) for word in sample]
#      10     for closest in closest_words:
#      11       sample.extend(closest)
#
# KeyError: 'Soccer'

# %% [markdown]
# ## As one can see, that doesn't make sense, since a lot of words are not in there.
# So next approach is to go through the vocabulary and calculate these words for each vocab in there.

# %%
vocabulary = pd.read_csv(path_root + data_root + '/vocabulary-attribute/vocab_cv.csv')

# %%
import time

closest_mapping = {}
counter = 0
for word in vocabulary['term']:
  print(len(vocabulary['term']) - counter, " words to go")
  start = time.time()
  closest = find_closest_embeddings_word(embeddings_dict[word], 10)
  closest_mapping[word] = closest
  end = time.time()
  print("Time for finding word:", end-start)
  break
# Out:
# 1672  words to go
# Time for finding word: 7.819216966629028

# %% [markdown]
# ## Calculating the nearest words costs ~30 seconds per word
# This results in 1700*30/3600 = ~14h. Definitely to long for a colab notebook.
# We will build a parallelized script to do so in the background on a different server. Using this approach we can reduce the time to 1.5h.

# %%
# Load Nearest words dict
import json
with open(path_root + data_root + '/vocabulary-attribute/final_mapping.json') as file:
  closest_words = json.load(file)

# %% [markdown]
# ## Next we're going to enhance the actual dataset before training/testing

# %%
from functools import reduce

def enhance(dset):
  tok_dset = tokenize_samples(dset)
  fil_dset = filter_stop_words(tok_dset)
  dset_enhanced = []

  failed_counter = 0
  worked_counter = 0

  for index in range(len(dset)):
    sample_enhanced = [dset[index]]
    sample = fil_dset[index]
    for word in sample:
      try:
        sample_enhanced.extend(closest_words[word])
        worked_counter += 1
      except:
        failed_counter += 1
    sample_enhanced = reduce(lambda a,b: a+ " " + b, sample_enhanced)
    dset_enhanced.append(sample_enhanced)

  print("Worked:", worked_counter, " Failed:", failed_counter)
  return dset_enhanced

X_train_enhanced = enhance(X_train)
X_val_enhanced = enhance(X_val)
# Out:
# Worked: 10600  Failed: 13628
# Worked: 4600  Failed: 5783

# %%
clf = SS3()
clf.fit(X_train_enhanced, y_train)
Evaluation.test(clf, X_val_enhanced, y_val)
# Out:
# Training:   0%|          | 0/2623 [00:00<?, ?it/s]
#
# Training:   6%|▋         | 168/2623 [00:00<00:01, 1679.77it/s]
#
# Training:  15%|█▌        | 403/2623 [00:00<00:01, 1834.89it/s]
#
# Training:  23%|██▎       | 603/2623 [00:00<00:01, 1874.23it/s]
#
# Training:  28%|██▊       | 736/2623 [00:00<00:02, 788.20it/s]
#
# Training:  32%|███▏      | 840/2623 [00:00<00:02, 691.96it/s]
#
# Training:  35%|███▌      | 929/2623 [00:01<00:02, 572.90it/s]
#
# Training:  38%|███▊      | 1004/2623 [00:01<00:02, 543.27it/s]
#
# Training:  47%|████▋     | 1226/2623 [00:01<00:01, 701.47it/s]
#
# Training:  56%|█████▌    | 1459/2623 [00:01<00:01, 887.28it/s]
#
# Training:  63%|██████▎   | 1646/2623 [00:01<00:01, 828.93it/s]
#
# Training:  72%|███████▏  | 1885/2623 [00:01<00:00, 1030.87it/s]
#
# Training:  78%|███████▊  | 2045/2623 [00:02<00:00, 895.28it/s]
#
# Training:  83%|████████▎ | 2178/2623 [00:02<00:00, 811.41it/s]
#
# Training:  87%|████████▋ | 2291/2623 [00:02<00:00, 369.08it/s]
#
# Training: 100%|██████████| 2623/2623 [00:03<00:00, 736.60it/s]
#
#
# Caching documents:   0%|          | 0/1125 [00:00<?, ?it/s]
#
# Caching documents:  25%|██▍       | 277/1125 [00:00<00:00, 1253.08it/s]
#
# Caching documents:  34%|███▍      | 388/1125 [00:00<00:00, 943.35it/s]
#
# Caching documents:  62%|██████▏   | 701/1125 [00:00<00:00, 1040.73it/s]
#
#
#
# Classification: 100%|██████████| 1125/1125 [00:00<00:00, 16645.30it/s]
#                        precision    recall  f1-score   support
#
#               general       0.67      0.83      0.74       529
#             usability       0.26      0.84      0.40        76
# operation_performance       0.43      0.86      0.57       139
#               quality       0.55      0.79      0.64       364
#           portability       0.12      0.93      0.21        14
#       design_features       0.30      0.91      0.45       106
#         style_options       0.17      0.80      0.28        45
#                 price       0.27      0.90      0.42        52
#         miscellaneous       0.20      0.69      0.31        75
#                prices       0.17      0.89      0.29        45
#          connectivity       0.24      0.50      0.32        22
#
#             micro avg       0.39      0.82      0.53      1467
#             macro avg       0.31      0.81      0.42      1467
#          weighted avg       0.49      0.82      0.59      1467
#           samples avg       0.47      0.84      0.56      1467
#
#
#  Exact Match Ratio: 0.166
#  Hamming Loss: 0.171
# [ updating evaluations cache ]
# 0.17074747474747476

# %%
s_l = span(0, 1, 10)
l_l = span(0, 5, 10)
p_l = span(0, 5, 10)
a_l = span(0, 1, 10)
best_s, best_l, best_p, best_a = Evaluation.grid_search(clf, X_train, y_train, s=s_l, l=l_l, p=p_l, a=a_l, n_grams=6)
# Out:
# Streaming output truncated to the last 5000 lines.
# Grid search:  72%|███████▏  | 7224/10000 [1:44:51<1:03:52,  1.38s/it]
#
# Grid search:  72%|███████▏  | 7225/10000 [1:44:53<1:04:47,  1.40s/it]
#
# Grid search:  72%|███████▏  | 7226/10000 [1:44:54<1:05:30,  1.42s/it]
#
# Grid search:  72%|███████▏  | 7227/10000 [1:44:56<1:06:04,  1.43s/it]
#
# Grid search:  72%|███████▏  | 7228/10000 [1:44:57<1:06:08,  1.43s/it]
#
# Grid search:  72%|███████▏  | 7229/10000 [1:44:59<1:06:09,  1.43s/it]
#
# Grid search:  72%|███████▏  | 7230/10000 [1:45:00<1:06:07,  1.43s/it]
#
# Grid search:  72%|███████▏  | 7232/10000 [1:45:02<1:00:07,  1.30s/it]
#
# Grid search:  72%|███████▏  | 7233/10000 [1:45:04<1:02:40,  1.36s/it]
#
# Grid search:  72%|███████▏  | 7234/10000 [1:45:05<1:03:41,  1.38s/it]
#
# Grid search:  72%|███████▏  | 7235/10000 [1:45:06<1:04:04,  1.39s/it]
#
# Grid search:  72%|███████▏  | 7236/10000 [1:45:08<1:06:10,  1.44s/it]
#
# Grid search:  72%|███████▏  | 7237/10000 [1:45:09<1:06:05,  1.44s/it]
#
# Grid search:  72%|███████▏  | 7238/10000 [1:45:11<1:06:19,  1.44s/it]
#
# Grid search:  72%|███████▏  | 7239/10000 [1:45:12<1:08:33,  1.49s/it]
#
# Grid search:  72%|███████▏  | 7240/10000 [1:45:14<1:07:42,  1.47s/it]
#
# Grid search:  72%|███████▏  | 7242/10000 [1:45:16<1:01:12,  1.33s/it]
#
# Grid search:  72%|███████▏  | 7243/10000 [1:45:17<1:02:24,  1.36s/it]
#
# Grid search:  72%|███████▏  | 7244/10000 [1:45:19<1:03:15,  1.38s/it]
#
# Grid search:  72%|███████▏  | 7245/10000 [1:45:20<1:04:28,  1.40s/it]
#
# Grid search:  72%|███████▏  | 7246/10000 [1:45:22<1:04:53,  1.41s/it]
#
# Grid search:  72%|███████▏  | 7247/10000 [1:45:23<1:05:13,  1.42s/it]
#
# Grid search:  72%|███████▏  | 7248/10000 [1:45:25<1:05:12,  1.42s/it]
#
# Grid search:  72%|███████▏  | 7249/10000 [1:45:26<1:05:23,  1.43s/it]
#
# Grid search:  72%|███████▎  | 7250/10000 [1:45:27<1:05:32,  1.43s/it]
#
# Grid search:  73%|███████▎  | 7252/10000 [1:45:29<59:28,  1.30s/it]
#
# Grid search:  73%|███████▎  | 7253/10000 [1:45:31<1:01:25,  1.34s/it]
#
# Grid search:  73%|███████▎  | 7254/10000 [1:45:32<1:02:39,  1.37s/it]
#
# Grid search:  73%|███████▎  | 7255/10000 [1:45:34<1:03:24,  1.39s/it]
#
# Grid search:  73%|███████▎  | 7256/10000 [1:45:35<1:04:12,  1.40s/it]
#
# Grid search:  73%|███████▎  | 7257/10000 [1:45:37<1:04:28,  1.41s/it]
#
# Grid search:  73%|███████▎  | 7258/10000 [1:45:38<1:04:38,  1.41s/it]
#
# Grid search:  73%|███████▎  | 7259/10000 [1:45:40<1:06:50,  1.46s/it]
#
# Grid search:  73%|███████▎  | 7260/10000 [1:45:41<1:06:48,  1.46s/it]
#
# Grid search:  73%|███████▎  | 7262/10000 [1:45:43<1:00:20,  1.32s/it]
#
# Grid search:  73%|███████▎  | 7263/10000 [1:45:44<1:01:54,  1.36s/it]
#
# Grid search:  73%|███████▎  | 7264/10000 [1:45:46<1:03:05,  1.38s/it]
#
# Grid search:  73%|███████▎  | 7265/10000 [1:45:47<1:03:48,  1.40s/it]
#
# Grid search:  73%|███████▎  | 7266/10000 [1:45:49<1:04:34,  1.42s/it]
#
# Grid search:  73%|███████▎  | 7267/10000 [1:45:50<1:04:56,  1.43s/it]
#
# Grid search:  73%|███████▎  | 7268/10000 [1:45:52<1:05:06,  1.43s/it]
#
# Grid search:  73%|███████▎  | 7269/10000 [1:45:53<1:05:15,  1.43s/it]
#
# Grid search:  73%|███████▎  | 7270/10000 [1:45:55<1:06:34,  1.46s/it]
#
# Grid search:  73%|███████▎  | 7272/10000 [1:45:57<59:53,  1.32s/it]
#
# Grid search:  73%|███████▎  | 7273/10000 [1:45:58<1:02:28,  1.37s/it]
#
# Grid search:  73%|███████▎  | 7274/10000 [1:46:00<1:04:15,  1.41s/it]
#
# Grid search:  73%|███████▎  | 7275/10000 [1:46:01<1:05:37,  1.45s/it]
#
# Grid search:  73%|███████▎  | 7276/10000 [1:46:03<1:06:24,  1.46s/it]
#
# Grid search:  73%|███████▎  | 7277/10000 [1:46:04<1:06:53,  1.47s/it]
#
# Grid search:  73%|███████▎  | 7278/10000 [1:46:06<1:07:39,  1.49s/it]
#
# Grid search:  73%|███████▎  | 7279/10000 [1:46:07<1:07:43,  1.49s/it]
#
# Grid search:  73%|███████▎  | 7280/10000 [1:46:09<1:08:52,  1.52s/it]
#
# Grid search:  73%|███████▎  | 7282/10000 [1:46:11<1:01:47,  1.36s/it]
#
# Grid search:  73%|███████▎  | 7283/10000 [1:46:12<1:03:50,  1.41s/it]
#
# Grid search:  73%|███████▎  | 7284/10000 [1:46:14<1:05:07,  1.44s/it]
#
# Grid search:  73%|███████▎  | 7285/10000 [1:46:15<1:06:00,  1.46s/it]
#
# Grid search:  73%|███████▎  | 7286/10000 [1:46:17<1:06:49,  1.48s/it]
#
# Grid search:  73%|███████▎  | 7287/10000 [1:46:18<1:07:07,  1.48s/it]
#
# Grid search:  73%|███████▎  | 7288/10000 [1:46:20<1:07:14,  1.49s/it]
#
# Grid search:  73%|███████▎  | 7289/10000 [1:46:21<1:07:28,  1.49s/it]
#
# Grid search:  73%|███████▎  | 7290/10000 [1:46:23<1:08:02,  1.51s/it]
#
# Grid search:  73%|███████▎  | 7292/10000 [1:46:25<1:01:15,  1.36s/it]
#
# Grid search:  73%|███████▎  | 7293/10000 [1:46:26<1:03:36,  1.41s/it]
#
# Grid search:  73%|███████▎  | 7294/10000 [1:46:28<1:05:21,  1.45s/it]
#
# Grid search:  73%|███████▎  | 7295/10000 [1:46:29<1:06:30,  1.48s/it]
#
# Grid search:  73%|███████▎  | 7296/10000 [1:46:31<1:07:21,  1.49s/it]
#
# Grid search:  73%|███████▎  | 7297/10000 [1:46:33<1:07:46,  1.50s/it]
#
# Grid search:  73%|███████▎  | 7298/10000 [1:46:34<1:07:53,  1.51s/it]
#
# Grid search:  73%|███████▎  | 7299/10000 [1:46:36<1:07:49,  1.51s/it]
#
# Grid search:  73%|███████▎  | 7300/10000 [1:46:37<1:07:46,  1.51s/it]
#
# Grid search:  73%|███████▎  | 7302/10000 [1:46:40<1:04:06,  1.43s/it]
#
# Grid search:  73%|███████▎  | 7303/10000 [1:46:41<1:08:16,  1.52s/it]
#
# Grid search:  73%|███████▎  | 7304/10000 [1:46:43<1:08:19,  1.52s/it]
#
# Grid search:  73%|███████▎  | 7305/10000 [1:46:44<1:08:27,  1.52s/it]
#
# Grid search:  73%|███████▎  | 7306/10000 [1:46:46<1:08:36,  1.53s/it]
#
# Grid search:  73%|███████▎  | 7307/10000 [1:46:47<1:08:37,  1.53s/it]
#
# Grid search:  73%|███████▎  | 7308/10000 [1:46:49<1:08:22,  1.52s/it]
#
# Grid search:  73%|███████▎  | 7309/10000 [1:46:50<1:08:38,  1.53s/it]
#
# Grid search:  73%|███████▎  | 7310/10000 [1:46:52<1:08:53,  1.54s/it]
#
# Grid search:  73%|███████▎  | 7312/10000 [1:46:54<1:01:52,  1.38s/it]
#
# Grid search:  73%|███████▎  | 7313/10000 [1:46:56<1:03:52,  1.43s/it]
#
# Grid search:  73%|███████▎  | 7314/10000 [1:46:57<1:05:14,  1.46s/it]
#
# Grid search:  73%|███████▎  | 7315/10000 [1:46:59<1:06:11,  1.48s/it]
#
# Grid search:  73%|███████▎  | 7316/10000 [1:47:00<1:06:37,  1.49s/it]
#
# Grid search:  73%|███████▎  | 7317/10000 [1:47:02<1:07:09,  1.50s/it]
#
# Grid search:  73%|███████▎  | 7318/10000 [1:47:03<1:07:31,  1.51s/it]
#
# Grid search:  73%|███████▎  | 7319/10000 [1:47:05<1:07:44,  1.52s/it]
#
# Grid search:  73%|███████▎  | 7320/10000 [1:47:06<1:07:35,  1.51s/it]
#
# Grid search:  73%|███████▎  | 7322/10000 [1:47:08<1:00:47,  1.36s/it]
#
# Grid search:  73%|███████▎  | 7323/10000 [1:47:10<1:02:41,  1.41s/it]
#
# Grid search:  73%|███████▎  | 7324/10000 [1:47:11<1:06:37,  1.49s/it]
#
# Grid search:  73%|███████▎  | 7325/10000 [1:47:13<1:07:09,  1.51s/it]
#
# Grid search:  73%|███████▎  | 7326/10000 [1:47:15<1:07:42,  1.52s/it]
#
# Grid search:  73%|███████▎  | 7327/10000 [1:47:16<1:07:35,  1.52s/it]
#
# Grid search:  73%|███████▎  | 7328/10000 [1:47:18<1:07:52,  1.52s/it]
#
# Grid search:  73%|███████▎  | 7329/10000 [1:47:19<1:07:41,  1.52s/it]
#
# Grid search:  73%|███████▎  | 7330/10000 [1:47:21<1:07:45,  1.52s/it]
#
# Grid search:  73%|███████▎  | 7332/10000 [1:47:23<1:01:03,  1.37s/it]
#
# Grid search:  73%|███████▎  | 7333/10000 [1:47:24<1:02:58,  1.42s/it]
#
# Grid search:  73%|███████▎  | 7334/10000 [1:47:26<1:04:14,  1.45s/it]
#
# Grid search:  73%|███████▎  | 7335/10000 [1:47:27<1:05:00,  1.46s/it]
#
# Grid search:  73%|███████▎  | 7336/10000 [1:47:29<1:05:34,  1.48s/it]
#
# Grid search:  73%|███████▎  | 7337/10000 [1:47:30<1:05:58,  1.49s/it]
#
# Grid search:  73%|███████▎  | 7338/10000 [1:47:32<1:06:32,  1.50s/it]
#
# Grid search:  73%|███████▎  | 7339/10000 [1:47:33<1:06:39,  1.50s/it]
#
# Grid search:  73%|███████▎  | 7340/10000 [1:47:35<1:06:42,  1.50s/it]
#
# Grid search:  73%|███████▎  | 7342/10000 [1:47:37<1:00:09,  1.36s/it]
#
# Grid search:  73%|███████▎  | 7343/10000 [1:47:38<1:02:08,  1.40s/it]
#
# Grid search:  73%|███████▎  | 7344/10000 [1:47:40<1:03:20,  1.43s/it]
#
# Grid search:  73%|███████▎  | 7345/10000 [1:47:41<1:06:18,  1.50s/it]
#
# Grid search:  73%|███████▎  | 7346/10000 [1:47:43<1:06:48,  1.51s/it]
#
# Grid search:  73%|███████▎  | 7347/10000 [1:47:45<1:06:56,  1.51s/it]
#
# Grid search:  73%|███████▎  | 7348/10000 [1:47:46<1:06:52,  1.51s/it]
#
# Grid search:  73%|███████▎  | 7349/10000 [1:47:48<1:07:00,  1.52s/it]
#
# Grid search:  74%|███████▎  | 7350/10000 [1:47:49<1:07:13,  1.52s/it]
#
# Grid search:  74%|███████▎  | 7352/10000 [1:47:51<1:00:23,  1.37s/it]
#
# Grid search:  74%|███████▎  | 7353/10000 [1:47:53<1:02:44,  1.42s/it]
#
# Grid search:  74%|███████▎  | 7354/10000 [1:47:54<1:04:01,  1.45s/it]
#
# Grid search:  74%|███████▎  | 7355/10000 [1:47:56<1:04:40,  1.47s/it]
#
# Grid search:  74%|███████▎  | 7356/10000 [1:47:57<1:05:17,  1.48s/it]
#
# Grid search:  74%|███████▎  | 7357/10000 [1:47:59<1:05:34,  1.49s/it]
#
# Grid search:  74%|███████▎  | 7358/10000 [1:48:00<1:05:56,  1.50s/it]
#
# Grid search:  74%|███████▎  | 7359/10000 [1:48:02<1:05:57,  1.50s/it]
#
# Grid search:  74%|███████▎  | 7360/10000 [1:48:03<1:06:15,  1.51s/it]
#
# Grid search:  74%|███████▎  | 7362/10000 [1:48:05<59:46,  1.36s/it]
#
# Grid search:  74%|███████▎  | 7363/10000 [1:48:07<1:02:00,  1.41s/it]
#
# Grid search:  74%|███████▎  | 7364/10000 [1:48:08<1:04:54,  1.48s/it]
#
# Grid search:  74%|███████▎  | 7365/10000 [1:48:10<1:05:37,  1.49s/it]
#
# Grid search:  74%|███████▎  | 7366/10000 [1:48:12<1:06:00,  1.50s/it]
#
# Grid search:  74%|███████▎  | 7367/10000 [1:48:13<1:06:32,  1.52s/it]
#
# Grid search:  74%|███████▎  | 7368/10000 [1:48:15<1:06:44,  1.52s/it]
#
# Grid search:  74%|███████▎  | 7369/10000 [1:48:16<1:06:49,  1.52s/it]
#
# Grid search:  74%|███████▎  | 7370/10000 [1:48:18<1:06:45,  1.52s/it]
#
# Grid search:  74%|███████▎  | 7372/10000 [1:48:20<59:47,  1.37s/it]
#
# Grid search:  74%|███████▎  | 7373/10000 [1:48:21<1:03:14,  1.44s/it]
#
# Grid search:  74%|███████▎  | 7374/10000 [1:48:23<1:04:44,  1.48s/it]
#
# Grid search:  74%|███████▍  | 7375/10000 [1:48:24<1:05:06,  1.49s/it]
#
# Grid search:  74%|███████▍  | 7376/10000 [1:48:26<1:05:40,  1.50s/it]
#
# Grid search:  74%|███████▍  | 7377/10000 [1:48:27<1:05:42,  1.50s/it]
#
# Grid search:  74%|███████▍  | 7378/10000 [1:48:29<1:06:02,  1.51s/it]
#
# Grid search:  74%|███████▍  | 7379/10000 [1:48:30<1:06:04,  1.51s/it]
#
# Grid search:  74%|███████▍  | 7380/10000 [1:48:32<1:06:17,  1.52s/it]
#
# Grid search:  74%|███████▍  | 7382/10000 [1:48:34<59:25,  1.36s/it]
#
# Grid search:  74%|███████▍  | 7383/10000 [1:48:35<1:01:32,  1.41s/it]
#
# Grid search:  74%|███████▍  | 7384/10000 [1:48:37<1:02:51,  1.44s/it]
#
# Grid search:  74%|███████▍  | 7385/10000 [1:48:39<1:04:08,  1.47s/it]
#
# Grid search:  74%|███████▍  | 7386/10000 [1:48:40<1:06:26,  1.53s/it]
#
# Grid search:  74%|███████▍  | 7387/10000 [1:48:42<1:06:33,  1.53s/it]
#
# Grid search:  74%|███████▍  | 7388/10000 [1:48:43<1:06:43,  1.53s/it]
#
# Grid search:  74%|███████▍  | 7389/10000 [1:48:45<1:06:42,  1.53s/it]
#
# Grid search:  74%|███████▍  | 7390/10000 [1:48:46<1:06:45,  1.53s/it]
#
# Grid search:  74%|███████▍  | 7392/10000 [1:48:48<59:40,  1.37s/it]
#
# Grid search:  74%|███████▍  | 7393/10000 [1:48:50<1:01:43,  1.42s/it]
#
# Grid search:  74%|███████▍  | 7394/10000 [1:48:51<1:03:22,  1.46s/it]
#
# Grid search:  74%|███████▍  | 7395/10000 [1:48:53<1:04:39,  1.49s/it]
#
# Grid search:  74%|███████▍  | 7396/10000 [1:48:55<1:05:23,  1.51s/it]
#
# Grid search:  74%|███████▍  | 7397/10000 [1:48:56<1:05:45,  1.52s/it]
#
# Grid search:  74%|███████▍  | 7398/10000 [1:48:58<1:06:00,  1.52s/it]
#
# Grid search:  74%|███████▍  | 7399/10000 [1:48:59<1:05:52,  1.52s/it]
#
# Grid search:  74%|███████▍  | 7400/10000 [1:49:01<1:05:51,  1.52s/it]
#
# Grid search:  74%|███████▍  | 7402/10000 [1:49:03<1:02:01,  1.43s/it]
#
# Grid search:  74%|███████▍  | 7403/10000 [1:49:05<1:03:18,  1.46s/it]
#
# Grid search:  74%|███████▍  | 7404/10000 [1:49:06<1:04:00,  1.48s/it]
#
# Grid search:  74%|███████▍  | 7405/10000 [1:49:08<1:04:24,  1.49s/it]
#
# Grid search:  74%|███████▍  | 7406/10000 [1:49:09<1:04:49,  1.50s/it]
#
# Grid search:  74%|███████▍  | 7407/10000 [1:49:11<1:06:47,  1.55s/it]
#
# Grid search:  74%|███████▍  | 7408/10000 [1:49:12<1:06:30,  1.54s/it]
#
# Grid search:  74%|███████▍  | 7409/10000 [1:49:14<1:06:34,  1.54s/it]
#
# Grid search:  74%|███████▍  | 7410/10000 [1:49:15<1:06:34,  1.54s/it]
#
# Grid search:  74%|███████▍  | 7412/10000 [1:49:17<59:42,  1.38s/it]
#
# Grid search:  74%|███████▍  | 7413/10000 [1:49:19<1:01:25,  1.42s/it]
#
# Grid search:  74%|███████▍  | 7414/10000 [1:49:21<1:02:33,  1.45s/it]
#
# Grid search:  74%|███████▍  | 7415/10000 [1:49:22<1:03:32,  1.47s/it]
#
# Grid search:  74%|███████▍  | 7416/10000 [1:49:24<1:04:28,  1.50s/it]
#
# Grid search:  74%|███████▍  | 7417/10000 [1:49:25<1:04:55,  1.51s/it]
#
# Grid search:  74%|███████▍  | 7418/10000 [1:49:27<1:05:05,  1.51s/it]
#
# Grid search:  74%|███████▍  | 7419/10000 [1:49:28<1:05:03,  1.51s/it]
#
# Grid search:  74%|███████▍  | 7420/10000 [1:49:30<1:04:57,  1.51s/it]
#
# Grid search:  74%|███████▍  | 7422/10000 [1:49:32<58:42,  1.37s/it]
#
# Grid search:  74%|███████▍  | 7423/10000 [1:49:33<1:00:48,  1.42s/it]
#
# Grid search:  74%|███████▍  | 7424/10000 [1:49:35<1:02:11,  1.45s/it]
#
# Grid search:  74%|███████▍  | 7425/10000 [1:49:36<1:03:07,  1.47s/it]
#
# Grid search:  74%|███████▍  | 7426/10000 [1:49:38<1:03:48,  1.49s/it]
#
# Grid search:  74%|███████▍  | 7427/10000 [1:49:39<1:05:49,  1.54s/it]
#
# Grid search:  74%|███████▍  | 7428/10000 [1:49:41<1:05:51,  1.54s/it]
#
# Grid search:  74%|███████▍  | 7429/10000 [1:49:43<1:05:58,  1.54s/it]
#
# Grid search:  74%|███████▍  | 7430/10000 [1:49:44<1:05:53,  1.54s/it]
#
# Grid search:  74%|███████▍  | 7432/10000 [1:49:46<59:06,  1.38s/it]
#
# Grid search:  74%|███████▍  | 7433/10000 [1:49:48<1:00:58,  1.43s/it]
#
# Grid search:  74%|███████▍  | 7434/10000 [1:49:49<1:02:07,  1.45s/it]
#
# Grid search:  74%|███████▍  | 7435/10000 [1:49:51<1:03:06,  1.48s/it]
#
# Grid search:  74%|███████▍  | 7436/10000 [1:49:52<1:03:36,  1.49s/it]
#
# Grid search:  74%|███████▍  | 7437/10000 [1:49:54<1:03:50,  1.49s/it]
#
# Grid search:  74%|███████▍  | 7438/10000 [1:49:55<1:04:33,  1.51s/it]
#
# Grid search:  74%|███████▍  | 7439/10000 [1:49:57<1:04:40,  1.52s/it]
#
# Grid search:  74%|███████▍  | 7440/10000 [1:49:58<1:04:49,  1.52s/it]
#
# Grid search:  74%|███████▍  | 7442/10000 [1:50:00<58:13,  1.37s/it]
#
# Grid search:  74%|███████▍  | 7443/10000 [1:50:02<1:00:06,  1.41s/it]
#
# Grid search:  74%|███████▍  | 7444/10000 [1:50:03<1:01:39,  1.45s/it]
#
# Grid search:  74%|███████▍  | 7445/10000 [1:50:05<1:02:36,  1.47s/it]
#
# Grid search:  74%|███████▍  | 7446/10000 [1:50:06<1:03:27,  1.49s/it]
#
# Grid search:  74%|███████▍  | 7447/10000 [1:50:08<1:03:53,  1.50s/it]
#
# Grid search:  74%|███████▍  | 7448/10000 [1:50:10<1:05:41,  1.54s/it]
#
# Grid search:  74%|███████▍  | 7449/10000 [1:50:11<1:05:45,  1.55s/it]
#
# Grid search:  74%|███████▍  | 7450/10000 [1:50:13<1:05:49,  1.55s/it]
#
# Grid search:  75%|███████▍  | 7452/10000 [1:50:15<58:59,  1.39s/it]
#
# Grid search:  75%|███████▍  | 7453/10000 [1:50:16<1:00:45,  1.43s/it]
#
# Grid search:  75%|███████▍  | 7454/10000 [1:50:18<1:02:04,  1.46s/it]
#
# Grid search:  75%|███████▍  | 7455/10000 [1:50:19<1:02:52,  1.48s/it]
#
# Grid search:  75%|███████▍  | 7456/10000 [1:50:21<1:03:34,  1.50s/it]
#
# Grid search:  75%|███████▍  | 7457/10000 [1:50:22<1:04:04,  1.51s/it]
#
# Grid search:  75%|███████▍  | 7458/10000 [1:50:24<1:04:12,  1.52s/it]
#
# Grid search:  75%|███████▍  | 7459/10000 [1:50:26<1:04:40,  1.53s/it]
#
# Grid search:  75%|███████▍  | 7460/10000 [1:50:27<1:04:41,  1.53s/it]
#
# Grid search:  75%|███████▍  | 7462/10000 [1:50:29<57:59,  1.37s/it]
#
# Grid search:  75%|███████▍  | 7463/10000 [1:50:31<1:00:06,  1.42s/it]
#
# Grid search:  75%|███████▍  | 7464/10000 [1:50:32<1:01:23,  1.45s/it]
#
# Grid search:  75%|███████▍  | 7465/10000 [1:50:34<1:02:18,  1.47s/it]
#
# Grid search:  75%|███████▍  | 7466/10000 [1:50:35<1:03:01,  1.49s/it]
#
# Grid search:  75%|███████▍  | 7467/10000 [1:50:37<1:03:26,  1.50s/it]
#
# Grid search:  75%|███████▍  | 7468/10000 [1:50:38<1:03:27,  1.50s/it]
#
# Grid search:  75%|███████▍  | 7469/10000 [1:50:40<1:03:46,  1.51s/it]
#
# Grid search:  75%|███████▍  | 7470/10000 [1:50:41<1:05:07,  1.54s/it]
#
# Grid search:  75%|███████▍  | 7472/10000 [1:50:43<58:21,  1.39s/it]
#
# Grid search:  75%|███████▍  | 7473/10000 [1:50:45<1:00:14,  1.43s/it]
#
# Grid search:  75%|███████▍  | 7474/10000 [1:50:46<1:01:17,  1.46s/it]
#
# Grid search:  75%|███████▍  | 7475/10000 [1:50:48<1:02:17,  1.48s/it]
#
# Grid search:  75%|███████▍  | 7476/10000 [1:50:50<1:02:52,  1.49s/it]
#
# Grid search:  75%|███████▍  | 7477/10000 [1:50:51<1:03:40,  1.51s/it]
#
# Grid search:  75%|███████▍  | 7478/10000 [1:50:53<1:04:00,  1.52s/it]
#
# Grid search:  75%|███████▍  | 7479/10000 [1:50:54<1:04:26,  1.53s/it]
#
# Grid search:  75%|███████▍  | 7480/10000 [1:50:56<1:04:28,  1.54s/it]
#
# Grid search:  75%|███████▍  | 7482/10000 [1:50:58<57:41,  1.37s/it]
#
# Grid search:  75%|███████▍  | 7483/10000 [1:50:59<59:36,  1.42s/it]
#
# Grid search:  75%|███████▍  | 7484/10000 [1:51:01<1:00:50,  1.45s/it]
#
# Grid search:  75%|███████▍  | 7485/10000 [1:51:02<1:01:54,  1.48s/it]
#
# Grid search:  75%|███████▍  | 7486/10000 [1:51:04<1:02:30,  1.49s/it]
#
# Grid search:  75%|███████▍  | 7487/10000 [1:51:05<1:02:58,  1.50s/it]
#
# Grid search:  75%|███████▍  | 7488/10000 [1:51:07<1:03:13,  1.51s/it]
#
# Grid search:  75%|███████▍  | 7489/10000 [1:51:08<1:03:12,  1.51s/it]
#
# Grid search:  75%|███████▍  | 7490/10000 [1:51:10<1:04:08,  1.53s/it]
#
# Grid search:  75%|███████▍  | 7492/10000 [1:51:12<57:25,  1.37s/it]
#
# Grid search:  75%|███████▍  | 7493/10000 [1:51:14<59:23,  1.42s/it]
#
# Grid search:  75%|███████▍  | 7494/10000 [1:51:15<1:00:50,  1.46s/it]
#
# Grid search:  75%|███████▍  | 7495/10000 [1:51:17<1:01:48,  1.48s/it]
#
# Grid search:  75%|███████▍  | 7496/10000 [1:51:18<1:02:34,  1.50s/it]
#
# Grid search:  75%|███████▍  | 7497/10000 [1:51:20<1:02:49,  1.51s/it]
#
# Grid search:  75%|███████▍  | 7498/10000 [1:51:21<1:03:19,  1.52s/it]
#
# Grid search:  75%|███████▍  | 7499/10000 [1:51:23<1:03:23,  1.52s/it]
#
# Grid search:  75%|███████▌  | 7500/10000 [1:51:24<1:03:53,  1.53s/it]
#
# Grid search:  75%|███████▌  | 7502/10000 [1:51:27<1:00:01,  1.44s/it]
#
# Grid search:  75%|███████▌  | 7503/10000 [1:51:28<1:01:00,  1.47s/it]
#
# Grid search:  75%|███████▌  | 7504/10000 [1:51:30<1:01:53,  1.49s/it]
#
# Grid search:  75%|███████▌  | 7505/10000 [1:51:31<1:02:28,  1.50s/it]
#
# Grid search:  75%|███████▌  | 7506/10000 [1:51:33<1:02:45,  1.51s/it]
#
# Grid search:  75%|███████▌  | 7507/10000 [1:51:34<1:03:02,  1.52s/it]
#
# Grid search:  75%|███████▌  | 7508/10000 [1:51:36<1:03:19,  1.52s/it]
#
# Grid search:  75%|███████▌  | 7509/10000 [1:51:38<1:03:41,  1.53s/it]
#
# Grid search:  75%|███████▌  | 7510/10000 [1:51:39<1:04:08,  1.55s/it]
#
# Grid search:  75%|███████▌  | 7512/10000 [1:51:41<57:39,  1.39s/it]
#
# Grid search:  75%|███████▌  | 7513/10000 [1:51:43<1:02:03,  1.50s/it]
#
# Grid search:  75%|███████▌  | 7514/10000 [1:51:44<1:02:37,  1.51s/it]
#
# Grid search:  75%|███████▌  | 7515/10000 [1:51:46<1:03:04,  1.52s/it]
#
# Grid search:  75%|███████▌  | 7516/10000 [1:51:47<1:03:04,  1.52s/it]
#
# Grid search:  75%|███████▌  | 7517/10000 [1:51:49<1:03:25,  1.53s/it]
#
# Grid search:  75%|███████▌  | 7518/10000 [1:51:51<1:03:30,  1.54s/it]
#
# Grid search:  75%|███████▌  | 7519/10000 [1:51:52<1:03:32,  1.54s/it]
#
# Grid search:  75%|███████▌  | 7520/10000 [1:51:54<1:03:40,  1.54s/it]
#
# Grid search:  75%|███████▌  | 7522/10000 [1:51:56<57:08,  1.38s/it]
#
# Grid search:  75%|███████▌  | 7523/10000 [1:51:57<58:45,  1.42s/it]
#
# Grid search:  75%|███████▌  | 7524/10000 [1:51:59<59:57,  1.45s/it]
#
# Grid search:  75%|███████▌  | 7525/10000 [1:52:00<1:00:58,  1.48s/it]
#
# Grid search:  75%|███████▌  | 7526/10000 [1:52:02<1:01:30,  1.49s/it]
#
# Grid search:  75%|███████▌  | 7527/10000 [1:52:03<1:02:13,  1.51s/it]
#
# Grid search:  75%|███████▌  | 7528/10000 [1:52:05<1:02:31,  1.52s/it]
#
# Grid search:  75%|███████▌  | 7529/10000 [1:52:06<1:03:13,  1.54s/it]
#
# Grid search:  75%|███████▌  | 7530/10000 [1:52:08<1:03:01,  1.53s/it]
#
# Grid search:  75%|███████▌  | 7532/10000 [1:52:10<58:09,  1.41s/it]
#
# Grid search:  75%|███████▌  | 7533/10000 [1:52:12<1:00:05,  1.46s/it]
#
# Grid search:  75%|███████▌  | 7534/10000 [1:52:13<1:00:59,  1.48s/it]
#
# Grid search:  75%|███████▌  | 7535/10000 [1:52:15<1:01:40,  1.50s/it]
#
# Grid search:  75%|███████▌  | 7536/10000 [1:52:16<1:02:13,  1.52s/it]
#
# Grid search:  75%|███████▌  | 7537/10000 [1:52:18<1:02:29,  1.52s/it]
#
# Grid search:  75%|███████▌  | 7538/10000 [1:52:20<1:02:27,  1.52s/it]
#
# Grid search:  75%|███████▌  | 7539/10000 [1:52:21<1:02:39,  1.53s/it]
#
# Grid search:  75%|███████▌  | 7540/10000 [1:52:23<1:02:36,  1.53s/it]
#
# Grid search:  75%|███████▌  | 7542/10000 [1:52:25<56:31,  1.38s/it]
#
# Grid search:  75%|███████▌  | 7543/10000 [1:52:26<58:25,  1.43s/it]
#
# Grid search:  75%|███████▌  | 7544/10000 [1:52:28<59:36,  1.46s/it]
#
# Grid search:  75%|███████▌  | 7545/10000 [1:52:29<1:00:40,  1.48s/it]
#
# Grid search:  75%|███████▌  | 7546/10000 [1:52:31<1:01:34,  1.51s/it]
#
# Grid search:  75%|███████▌  | 7547/10000 [1:52:32<1:02:26,  1.53s/it]
#
# Grid search:  75%|███████▌  | 7548/10000 [1:52:34<1:02:32,  1.53s/it]
#
# Grid search:  75%|███████▌  | 7549/10000 [1:52:36<1:02:43,  1.54s/it]
#
# Grid search:  76%|███████▌  | 7550/10000 [1:52:37<1:02:46,  1.54s/it]
#
# Grid search:  76%|███████▌  | 7552/10000 [1:52:39<56:26,  1.38s/it]
#
# Grid search:  76%|███████▌  | 7553/10000 [1:52:41<1:00:54,  1.49s/it]
#
# Grid search:  76%|███████▌  | 7554/10000 [1:52:42<1:01:35,  1.51s/it]
#
# Grid search:  76%|███████▌  | 7555/10000 [1:52:44<1:01:53,  1.52s/it]
#
# Grid search:  76%|███████▌  | 7556/10000 [1:52:45<1:02:09,  1.53s/it]
#
# Grid search:  76%|███████▌  | 7557/10000 [1:52:47<1:02:26,  1.53s/it]
#
# Grid search:  76%|███████▌  | 7558/10000 [1:52:49<1:02:34,  1.54s/it]
#
# Grid search:  76%|███████▌  | 7559/10000 [1:52:50<1:02:38,  1.54s/it]
#
# Grid search:  76%|███████▌  | 7560/10000 [1:52:52<1:02:50,  1.55s/it]
#
# Grid search:  76%|███████▌  | 7562/10000 [1:52:54<56:25,  1.39s/it]
#
# Grid search:  76%|███████▌  | 7563/10000 [1:52:55<58:13,  1.43s/it]
#
# Grid search:  76%|███████▌  | 7564/10000 [1:52:57<59:28,  1.46s/it]
#
# Grid search:  76%|███████▌  | 7565/10000 [1:52:58<1:00:06,  1.48s/it]
#
# Grid search:  76%|███████▌  | 7566/10000 [1:53:00<1:00:28,  1.49s/it]
#
# Grid search:  76%|███████▌  | 7567/10000 [1:53:01<1:00:51,  1.50s/it]
#
# Grid search:  76%|███████▌  | 7568/10000 [1:53:03<1:01:29,  1.52s/it]
#
# Grid search:  76%|███████▌  | 7569/10000 [1:53:04<1:01:46,  1.52s/it]
#
# Grid search:  76%|███████▌  | 7570/10000 [1:53:06<1:01:55,  1.53s/it]
#
# Grid search:  76%|███████▌  | 7572/10000 [1:53:08<55:22,  1.37s/it]
#
# Grid search:  76%|███████▌  | 7573/10000 [1:53:09<56:59,  1.41s/it]
#
# Grid search:  76%|███████▌  | 7574/10000 [1:53:11<58:20,  1.44s/it]
#
# Grid search:  76%|███████▌  | 7575/10000 [1:53:13<1:00:30,  1.50s/it]
#
# Grid search:  76%|███████▌  | 7576/10000 [1:53:14<1:01:17,  1.52s/it]
#
# Grid search:  76%|███████▌  | 7577/10000 [1:53:16<1:01:29,  1.52s/it]
#
# Grid search:  76%|███████▌  | 7578/10000 [1:53:17<1:01:29,  1.52s/it]
#
# Grid search:  76%|███████▌  | 7579/10000 [1:53:19<1:01:25,  1.52s/it]
#
# Grid search:  76%|███████▌  | 7580/10000 [1:53:20<1:01:52,  1.53s/it]
#
# Grid search:  76%|███████▌  | 7582/10000 [1:53:22<55:21,  1.37s/it]
#
# Grid search:  76%|███████▌  | 7583/10000 [1:53:24<57:14,  1.42s/it]
#
# Grid search:  76%|███████▌  | 7584/10000 [1:53:25<58:53,  1.46s/it]
#
# Grid search:  76%|███████▌  | 7585/10000 [1:53:27<59:50,  1.49s/it]
#
# Grid search:  76%|███████▌  | 7586/10000 [1:53:28<1:00:18,  1.50s/it]
#
# Grid search:  76%|███████▌  | 7587/10000 [1:53:30<1:00:42,  1.51s/it]
#
# Grid search:  76%|███████▌  | 7588/10000 [1:53:32<1:01:08,  1.52s/it]
#
# Grid search:  76%|███████▌  | 7589/10000 [1:53:33<1:01:29,  1.53s/it]
#
# Grid search:  76%|███████▌  | 7590/10000 [1:53:35<1:01:30,  1.53s/it]
#
# Grid search:  76%|███████▌  | 7592/10000 [1:53:37<55:07,  1.37s/it]
#
# Grid search:  76%|███████▌  | 7593/10000 [1:53:38<56:50,  1.42s/it]
#
# Grid search:  76%|███████▌  | 7594/10000 [1:53:40<58:05,  1.45s/it]
#
# Grid search:  76%|███████▌  | 7595/10000 [1:53:41<58:57,  1.47s/it]
#
# Grid search:  76%|███████▌  | 7596/10000 [1:53:43<59:49,  1.49s/it]
#
# Grid search:  76%|███████▌  | 7597/10000 [1:53:44<1:01:30,  1.54s/it]
#
# Grid search:  76%|███████▌  | 7598/10000 [1:53:46<1:01:37,  1.54s/it]
#
# Grid search:  76%|███████▌  | 7599/10000 [1:53:48<1:01:50,  1.55s/it]
#
# Grid search:  76%|███████▌  | 7600/10000 [1:53:49<1:01:42,  1.54s/it]
#
# Grid search:  76%|███████▌  | 7602/10000 [1:53:52<57:51,  1.45s/it]
#
# Grid search:  76%|███████▌  | 7603/10000 [1:53:53<59:02,  1.48s/it]
#
# Grid search:  76%|███████▌  | 7604/10000 [1:53:55<59:55,  1.50s/it]
#
# Grid search:  76%|███████▌  | 7605/10000 [1:53:56<1:00:17,  1.51s/it]
#
# Grid search:  76%|███████▌  | 7606/10000 [1:53:58<1:00:39,  1.52s/it]
#
# Grid search:  76%|███████▌  | 7607/10000 [1:53:59<1:00:59,  1.53s/it]
#
# Grid search:  76%|███████▌  | 7608/10000 [1:54:01<1:01:25,  1.54s/it]
#
# Grid search:  76%|███████▌  | 7609/10000 [1:54:02<1:01:33,  1.54s/it]
#
# Grid search:  76%|███████▌  | 7610/10000 [1:54:04<1:01:24,  1.54s/it]
#
# Grid search:  76%|███████▌  | 7612/10000 [1:54:06<55:09,  1.39s/it]
#
# Grid search:  76%|███████▌  | 7613/10000 [1:54:07<56:57,  1.43s/it]
#
# Grid search:  76%|███████▌  | 7614/10000 [1:54:09<58:24,  1.47s/it]
#
# Grid search:  76%|███████▌  | 7615/10000 [1:54:11<59:30,  1.50s/it]
#
# Grid search:  76%|███████▌  | 7616/10000 [1:54:12<1:00:04,  1.51s/it]
#
# Grid search:  76%|███████▌  | 7617/10000 [1:54:14<1:00:24,  1.52s/it]
#
# Grid search:  76%|███████▌  | 7618/10000 [1:54:15<1:00:48,  1.53s/it]
#
# Grid search:  76%|███████▌  | 7619/10000 [1:54:17<1:02:32,  1.58s/it]
#
# Grid search:  76%|███████▌  | 7620/10000 [1:54:18<1:02:15,  1.57s/it]
#
# Grid search:  76%|███████▌  | 7622/10000 [1:54:21<55:38,  1.40s/it]
#
# Grid search:  76%|███████▌  | 7623/10000 [1:54:22<57:35,  1.45s/it]
#
# Grid search:  76%|███████▌  | 7624/10000 [1:54:24<58:59,  1.49s/it]
#
# Grid search:  76%|███████▋  | 7625/10000 [1:54:25<1:00:01,  1.52s/it]
#
# Grid search:  76%|███████▋  | 7626/10000 [1:54:27<1:00:51,  1.54s/it]
#
# Grid search:  76%|███████▋  | 7627/10000 [1:54:28<1:00:52,  1.54s/it]
#
# Grid search:  76%|███████▋  | 7628/10000 [1:54:30<1:01:05,  1.55s/it]
#
# Grid search:  76%|███████▋  | 7629/10000 [1:54:31<1:01:03,  1.54s/it]
#
# Grid search:  76%|███████▋  | 7630/10000 [1:54:33<1:01:14,  1.55s/it]
#
# Grid search:  76%|███████▋  | 7632/10000 [1:54:35<54:53,  1.39s/it]
#
# Grid search:  76%|███████▋  | 7633/10000 [1:54:37<56:44,  1.44s/it]
#
# Grid search:  76%|███████▋  | 7634/10000 [1:54:38<58:10,  1.48s/it]
#
# Grid search:  76%|███████▋  | 7635/10000 [1:54:40<59:15,  1.50s/it]
#
# Grid search:  76%|███████▋  | 7636/10000 [1:54:41<59:53,  1.52s/it]
#
# Grid search:  76%|███████▋  | 7637/10000 [1:54:43<1:00:33,  1.54s/it]
#
# Grid search:  76%|███████▋  | 7638/10000 [1:54:44<1:01:01,  1.55s/it]
#
# Grid search:  76%|███████▋  | 7639/10000 [1:54:46<1:00:58,  1.55s/it]
#
# Grid search:  76%|███████▋  | 7640/10000 [1:54:48<1:02:07,  1.58s/it]
#
# Grid search:  76%|███████▋  | 7642/10000 [1:54:50<55:32,  1.41s/it]
#
# Grid search:  76%|███████▋  | 7643/10000 [1:54:51<57:10,  1.46s/it]
#
# Grid search:  76%|███████▋  | 7644/10000 [1:54:53<58:24,  1.49s/it]
#
# Grid search:  76%|███████▋  | 7645/10000 [1:54:54<59:28,  1.52s/it]
#
# Grid search:  76%|███████▋  | 7646/10000 [1:54:56<1:00:01,  1.53s/it]
#
# Grid search:  76%|███████▋  | 7647/10000 [1:54:58<1:00:17,  1.54s/it]
#
# Grid search:  76%|███████▋  | 7648/10000 [1:54:59<1:00:16,  1.54s/it]
#
# Grid search:  76%|███████▋  | 7649/10000 [1:55:01<1:00:25,  1.54s/it]
#
# Grid search:  76%|███████▋  | 7650/10000 [1:55:02<1:00:33,  1.55s/it]
#
# Grid search:  77%|███████▋  | 7652/10000 [1:55:04<54:21,  1.39s/it]
#
# Grid search:  77%|███████▋  | 7653/10000 [1:55:06<56:15,  1.44s/it]
#
# Grid search:  77%|███████▋  | 7654/10000 [1:55:07<57:31,  1.47s/it]
#
# Grid search:  77%|███████▋  | 7655/10000 [1:55:09<58:14,  1.49s/it]
#
# Grid search:  77%|███████▋  | 7656/10000 [1:55:10<59:06,  1.51s/it]
#
# Grid search:  77%|███████▋  | 7657/10000 [1:55:12<59:36,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7658/10000 [1:55:14<59:54,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7659/10000 [1:55:15<1:00:02,  1.54s/it]
#
# Grid search:  77%|███████▋  | 7660/10000 [1:55:17<1:01:21,  1.57s/it]
#
# Grid search:  77%|███████▋  | 7662/10000 [1:55:19<54:43,  1.40s/it]
#
# Grid search:  77%|███████▋  | 7663/10000 [1:55:20<57:28,  1.48s/it]
#
# Grid search:  77%|███████▋  | 7664/10000 [1:55:22<57:59,  1.49s/it]
#
# Grid search:  77%|███████▋  | 7665/10000 [1:55:23<58:32,  1.50s/it]
#
# Grid search:  77%|███████▋  | 7666/10000 [1:55:25<59:28,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7667/10000 [1:55:27<59:29,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7668/10000 [1:55:28<59:32,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7669/10000 [1:55:30<59:33,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7670/10000 [1:55:31<59:52,  1.54s/it]
#
# Grid search:  77%|███████▋  | 7672/10000 [1:55:33<53:38,  1.38s/it]
#
# Grid search:  77%|███████▋  | 7673/10000 [1:55:35<55:22,  1.43s/it]
#
# Grid search:  77%|███████▋  | 7674/10000 [1:55:36<56:37,  1.46s/it]
#
# Grid search:  77%|███████▋  | 7675/10000 [1:55:38<57:14,  1.48s/it]
#
# Grid search:  77%|███████▋  | 7676/10000 [1:55:39<57:30,  1.48s/it]
#
# Grid search:  77%|███████▋  | 7677/10000 [1:55:41<57:50,  1.49s/it]
#
# Grid search:  77%|███████▋  | 7678/10000 [1:55:42<58:22,  1.51s/it]
#
# Grid search:  77%|███████▋  | 7679/10000 [1:55:44<58:39,  1.52s/it]
#
# Grid search:  77%|███████▋  | 7680/10000 [1:55:45<58:43,  1.52s/it]
#
# Grid search:  77%|███████▋  | 7682/10000 [1:55:47<52:43,  1.36s/it]
#
# Grid search:  77%|███████▋  | 7683/10000 [1:55:49<54:26,  1.41s/it]
#
# Grid search:  77%|███████▋  | 7684/10000 [1:55:51<56:06,  1.45s/it]
#
# Grid search:  77%|███████▋  | 7685/10000 [1:55:52<58:11,  1.51s/it]
#
# Grid search:  77%|███████▋  | 7686/10000 [1:55:54<58:46,  1.52s/it]
#
# Grid search:  77%|███████▋  | 7687/10000 [1:55:55<59:06,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7688/10000 [1:55:57<59:04,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7689/10000 [1:55:58<59:05,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7690/10000 [1:56:00<59:09,  1.54s/it]
#
# Grid search:  77%|███████▋  | 7692/10000 [1:56:02<53:03,  1.38s/it]
#
# Grid search:  77%|███████▋  | 7693/10000 [1:56:03<54:57,  1.43s/it]
#
# Grid search:  77%|███████▋  | 7694/10000 [1:56:05<56:19,  1.47s/it]
#
# Grid search:  77%|███████▋  | 7695/10000 [1:56:07<57:05,  1.49s/it]
#
# Grid search:  77%|███████▋  | 7696/10000 [1:56:08<57:33,  1.50s/it]
#
# Grid search:  77%|███████▋  | 7697/10000 [1:56:10<58:01,  1.51s/it]
#
# Grid search:  77%|███████▋  | 7698/10000 [1:56:11<58:36,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7699/10000 [1:56:13<58:48,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7700/10000 [1:56:14<58:50,  1.54s/it]
#
# Grid search:  77%|███████▋  | 7702/10000 [1:56:17<55:15,  1.44s/it]
#
# Grid search:  77%|███████▋  | 7703/10000 [1:56:18<56:05,  1.47s/it]
#
# Grid search:  77%|███████▋  | 7704/10000 [1:56:20<56:53,  1.49s/it]
#
# Grid search:  77%|███████▋  | 7705/10000 [1:56:21<57:23,  1.50s/it]
#
# Grid search:  77%|███████▋  | 7706/10000 [1:56:23<59:47,  1.56s/it]
#
# Grid search:  77%|███████▋  | 7707/10000 [1:56:25<59:46,  1.56s/it]
#
# Grid search:  77%|███████▋  | 7708/10000 [1:56:26<59:20,  1.55s/it]
#
# Grid search:  77%|███████▋  | 7709/10000 [1:56:28<59:07,  1.55s/it]
#
# Grid search:  77%|███████▋  | 7710/10000 [1:56:29<59:03,  1.55s/it]
#
# Grid search:  77%|███████▋  | 7712/10000 [1:56:31<52:56,  1.39s/it]
#
# Grid search:  77%|███████▋  | 7713/10000 [1:56:33<54:55,  1.44s/it]
#
# Grid search:  77%|███████▋  | 7714/10000 [1:56:34<56:07,  1.47s/it]
#
# Grid search:  77%|███████▋  | 7715/10000 [1:56:36<56:56,  1.49s/it]
#
# Grid search:  77%|███████▋  | 7716/10000 [1:56:37<57:25,  1.51s/it]
#
# Grid search:  77%|███████▋  | 7717/10000 [1:56:39<58:01,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7718/10000 [1:56:41<58:16,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7719/10000 [1:56:42<58:12,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7720/10000 [1:56:44<58:14,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7722/10000 [1:56:46<52:37,  1.39s/it]
#
# Grid search:  77%|███████▋  | 7723/10000 [1:56:47<54:40,  1.44s/it]
#
# Grid search:  77%|███████▋  | 7724/10000 [1:56:49<56:08,  1.48s/it]
#
# Grid search:  77%|███████▋  | 7725/10000 [1:56:50<57:16,  1.51s/it]
#
# Grid search:  77%|███████▋  | 7726/10000 [1:56:52<57:50,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7727/10000 [1:56:54<59:22,  1.57s/it]
#
# Grid search:  77%|███████▋  | 7728/10000 [1:56:55<59:40,  1.58s/it]
#
# Grid search:  77%|███████▋  | 7729/10000 [1:56:57<59:16,  1.57s/it]
#
# Grid search:  77%|███████▋  | 7730/10000 [1:56:58<58:53,  1.56s/it]
#
# Grid search:  77%|███████▋  | 7732/10000 [1:57:00<52:37,  1.39s/it]
#
# Grid search:  77%|███████▋  | 7733/10000 [1:57:02<54:36,  1.45s/it]
#
# Grid search:  77%|███████▋  | 7734/10000 [1:57:03<55:54,  1.48s/it]
#
# Grid search:  77%|███████▋  | 7735/10000 [1:57:05<56:27,  1.50s/it]
#
# Grid search:  77%|███████▋  | 7736/10000 [1:57:07<57:00,  1.51s/it]
#
# Grid search:  77%|███████▋  | 7737/10000 [1:57:08<57:05,  1.51s/it]
#
# Grid search:  77%|███████▋  | 7738/10000 [1:57:10<57:32,  1.53s/it]
#
# Grid search:  77%|███████▋  | 7739/10000 [1:57:11<58:06,  1.54s/it]
#
# Grid search:  77%|███████▋  | 7740/10000 [1:57:13<58:22,  1.55s/it]
#
# Grid search:  77%|███████▋  | 7742/10000 [1:57:15<52:12,  1.39s/it]
#
# Grid search:  77%|███████▋  | 7743/10000 [1:57:16<53:52,  1.43s/it]
#
# Grid search:  77%|███████▋  | 7744/10000 [1:57:18<55:03,  1.46s/it]
#
# Grid search:  77%|███████▋  | 7745/10000 [1:57:19<55:42,  1.48s/it]
#
# Grid search:  77%|███████▋  | 7746/10000 [1:57:21<56:24,  1.50s/it]
#
# Grid search:  77%|███████▋  | 7747/10000 [1:57:22<56:52,  1.51s/it]
#
# Grid search:  77%|███████▋  | 7748/10000 [1:57:24<57:13,  1.52s/it]
#
# Grid search:  77%|███████▋  | 7749/10000 [1:57:26<58:48,  1.57s/it]
#
# Grid search:  78%|███████▊  | 7750/10000 [1:57:27<58:33,  1.56s/it]
#
# Grid search:  78%|███████▊  | 7752/10000 [1:57:29<52:16,  1.40s/it]
#
# Grid search:  78%|███████▊  | 7753/10000 [1:57:31<54:11,  1.45s/it]
#
# Grid search:  78%|███████▊  | 7754/10000 [1:57:32<55:08,  1.47s/it]
#
# Grid search:  78%|███████▊  | 7755/10000 [1:57:34<55:51,  1.49s/it]
#
# Grid search:  78%|███████▊  | 7756/10000 [1:57:35<56:27,  1.51s/it]
#
# Grid search:  78%|███████▊  | 7757/10000 [1:57:37<56:45,  1.52s/it]
#
# Grid search:  78%|███████▊  | 7758/10000 [1:57:39<57:20,  1.53s/it]
#
# Grid search:  78%|███████▊  | 7759/10000 [1:57:40<57:18,  1.53s/it]
#
# Grid search:  78%|███████▊  | 7760/10000 [1:57:42<57:26,  1.54s/it]
#
# Grid search:  78%|███████▊  | 7762/10000 [1:57:44<51:33,  1.38s/it]
#
# Grid search:  78%|███████▊  | 7763/10000 [1:57:45<53:28,  1.43s/it]
#
# Grid search:  78%|███████▊  | 7764/10000 [1:57:47<54:49,  1.47s/it]
#
# Grid search:  78%|███████▊  | 7765/10000 [1:57:48<55:39,  1.49s/it]
#
# Grid search:  78%|███████▊  | 7766/10000 [1:57:50<56:09,  1.51s/it]
#
# Grid search:  78%|███████▊  | 7767/10000 [1:57:51<56:33,  1.52s/it]
#
# Grid search:  78%|███████▊  | 7768/10000 [1:57:53<56:58,  1.53s/it]
#
# Grid search:  78%|███████▊  | 7769/10000 [1:57:55<57:06,  1.54s/it]
#
# Grid search:  78%|███████▊  | 7770/10000 [1:57:56<58:21,  1.57s/it]
#
# Grid search:  78%|███████▊  | 7772/10000 [1:57:58<52:15,  1.41s/it]
#
# Grid search:  78%|███████▊  | 7773/10000 [1:58:00<53:48,  1.45s/it]
#
# Grid search:  78%|███████▊  | 7774/10000 [1:58:01<55:12,  1.49s/it]
#
# Grid search:  78%|███████▊  | 7775/10000 [1:58:03<56:08,  1.51s/it]
#
# Grid search:  78%|███████▊  | 7776/10000 [1:58:04<56:40,  1.53s/it]
#
# Grid search:  78%|███████▊  | 7777/10000 [1:58:06<57:08,  1.54s/it]
#
# Grid search:  78%|███████▊  | 7778/10000 [1:58:08<57:24,  1.55s/it]
#
# Grid search:  78%|███████▊  | 7779/10000 [1:58:09<57:53,  1.56s/it]
#
# Grid search:  78%|███████▊  | 7780/10000 [1:58:11<58:08,  1.57s/it]
#
# Grid search:  78%|███████▊  | 7782/10000 [1:58:13<52:07,  1.41s/it]
#
# Grid search:  78%|███████▊  | 7783/10000 [1:58:14<53:57,  1.46s/it]
#
# Grid search:  78%|███████▊  | 7784/10000 [1:58:16<55:13,  1.50s/it]
#
# Grid search:  78%|███████▊  | 7785/10000 [1:58:18<56:02,  1.52s/it]
#
# Grid search:  78%|███████▊  | 7786/10000 [1:58:19<56:41,  1.54s/it]
#
# Grid search:  78%|███████▊  | 7787/10000 [1:58:21<57:51,  1.57s/it]
#
# Grid search:  78%|███████▊  | 7788/10000 [1:58:22<58:13,  1.58s/it]
#
# Grid search:  78%|███████▊  | 7789/10000 [1:58:24<58:24,  1.58s/it]
#
# Grid search:  78%|███████▊  | 7790/10000 [1:58:26<58:47,  1.60s/it]
#
# Grid search:  78%|███████▊  | 7792/10000 [1:58:28<52:38,  1.43s/it]
#
# Grid search:  78%|███████▊  | 7793/10000 [1:58:29<55:27,  1.51s/it]
#
# Grid search:  78%|███████▊  | 7794/10000 [1:58:31<55:51,  1.52s/it]
#
# Grid search:  78%|███████▊  | 7795/10000 [1:58:33<56:12,  1.53s/it]
#
# Grid search:  78%|███████▊  | 7796/10000 [1:58:34<56:37,  1.54s/it]
#
# Grid search:  78%|███████▊  | 7797/10000 [1:58:36<56:42,  1.54s/it]
#
# Grid search:  78%|███████▊  | 7798/10000 [1:58:37<56:12,  1.53s/it]
#
# Grid search:  78%|███████▊  | 7799/10000 [1:58:39<55:39,  1.52s/it]
#
# Grid search:  78%|███████▊  | 7800/10000 [1:58:40<55:21,  1.51s/it]
#
# Grid search:  78%|███████▊  | 7802/10000 [1:58:43<52:04,  1.42s/it]
#
# Grid search:  78%|███████▊  | 7803/10000 [1:58:44<52:36,  1.44s/it]
#
# Grid search:  78%|███████▊  | 7804/10000 [1:58:46<53:56,  1.47s/it]
#
# Grid search:  78%|███████▊  | 7805/10000 [1:58:47<54:42,  1.50s/it]
#
# Grid search:  78%|███████▊  | 7806/10000 [1:58:49<54:54,  1.50s/it]
#
# Grid search:  78%|███████▊  | 7807/10000 [1:58:50<55:00,  1.51s/it]
#
# Grid search:  78%|███████▊  | 7808/10000 [1:58:52<55:39,  1.52s/it]
#
# Grid search:  78%|███████▊  | 7809/10000 [1:58:53<55:28,  1.52s/it]
#
# Grid search:  78%|███████▊  | 7810/10000 [1:58:55<55:06,  1.51s/it]
#
# Grid search:  78%|███████▊  | 7812/10000 [1:58:57<49:20,  1.35s/it]
#
# Grid search:  78%|███████▊  | 7813/10000 [1:58:58<50:48,  1.39s/it]
#
# Grid search:  78%|███████▊  | 7814/10000 [1:59:00<52:16,  1.43s/it]
#
# Grid search:  78%|███████▊  | 7815/10000 [1:59:01<55:02,  1.51s/it]
#
# Grid search:  78%|███████▊  | 7816/10000 [1:59:03<56:05,  1.54s/it]
#
# Grid search:  78%|███████▊  | 7817/10000 [1:59:05<56:41,  1.56s/it]
#
# Grid search:  78%|███████▊  | 7818/10000 [1:59:06<57:00,  1.57s/it]
#
# Grid search:  78%|███████▊  | 7819/10000 [1:59:08<57:04,  1.57s/it]
#
# Grid search:  78%|███████▊  | 7820/10000 [1:59:09<56:23,  1.55s/it]
#
# Grid search:  78%|███████▊  | 7822/10000 [1:59:11<50:25,  1.39s/it]
#
# Grid search:  78%|███████▊  | 7823/10000 [1:59:13<52:10,  1.44s/it]
#
# Grid search:  78%|███████▊  | 7824/10000 [1:59:14<53:13,  1.47s/it]
#
# Grid search:  78%|███████▊  | 7825/10000 [1:59:16<54:06,  1.49s/it]
#
# Grid search:  78%|███████▊  | 7826/10000 [1:59:17<53:56,  1.49s/it]
#
# Grid search:  78%|███████▊  | 7827/10000 [1:59:19<53:53,  1.49s/it]
#
# Grid search:  78%|███████▊  | 7828/10000 [1:59:21<55:12,  1.53s/it]
#
# Grid search:  78%|███████▊  | 7829/10000 [1:59:22<56:26,  1.56s/it]
#
# Grid search:  78%|███████▊  | 7830/10000 [1:59:24<57:03,  1.58s/it]
#
# Grid search:  78%|███████▊  | 7832/10000 [1:59:26<51:25,  1.42s/it]
#
# Grid search:  78%|███████▊  | 7833/10000 [1:59:28<53:25,  1.48s/it]
#
# Grid search:  78%|███████▊  | 7834/10000 [1:59:29<54:41,  1.52s/it]
#
# Grid search:  78%|███████▊  | 7835/10000 [1:59:31<55:40,  1.54s/it]
#
# Grid search:  78%|███████▊  | 7836/10000 [1:59:32<56:14,  1.56s/it]
#
# Grid search:  78%|███████▊  | 7837/10000 [1:59:34<57:15,  1.59s/it]
#
# Grid search:  78%|███████▊  | 7838/10000 [1:59:36<57:06,  1.58s/it]
#
# Grid search:  78%|███████▊  | 7839/10000 [1:59:37<56:32,  1.57s/it]
#
# Grid search:  78%|███████▊  | 7840/10000 [1:59:39<56:06,  1.56s/it]
#
# Grid search:  78%|███████▊  | 7842/10000 [1:59:41<49:55,  1.39s/it]
#
# Grid search:  78%|███████▊  | 7843/10000 [1:59:42<51:13,  1.42s/it]
#
# Grid search:  78%|███████▊  | 7844/10000 [1:59:44<52:18,  1.46s/it]
#
# Grid search:  78%|███████▊  | 7845/10000 [1:59:45<53:29,  1.49s/it]
#
# Grid search:  78%|███████▊  | 7846/10000 [1:59:47<54:13,  1.51s/it]
#
# Grid search:  78%|███████▊  | 7847/10000 [1:59:48<54:47,  1.53s/it]
#
# Grid search:  78%|███████▊  | 7848/10000 [1:59:50<54:58,  1.53s/it]
#
# Grid search:  78%|███████▊  | 7849/10000 [1:59:51<55:12,  1.54s/it]
#
# Grid search:  78%|███████▊  | 7850/10000 [1:59:53<55:51,  1.56s/it]
#
# Grid search:  79%|███████▊  | 7852/10000 [1:59:55<50:23,  1.41s/it]
#
# Grid search:  79%|███████▊  | 7853/10000 [1:59:57<52:22,  1.46s/it]
#
# Grid search:  79%|███████▊  | 7854/10000 [1:59:58<53:48,  1.50s/it]
#
# Grid search:  79%|███████▊  | 7855/10000 [2:00:00<55:11,  1.54s/it]
#
# Grid search:  79%|███████▊  | 7856/10000 [2:00:02<56:11,  1.57s/it]
#
# Grid search:  79%|███████▊  | 7857/10000 [2:00:03<56:16,  1.58s/it]
#
# Grid search:  79%|███████▊  | 7858/10000 [2:00:05<56:00,  1.57s/it]
#
# Grid search:  79%|███████▊  | 7859/10000 [2:00:06<56:28,  1.58s/it]
#
# Grid search:  79%|███████▊  | 7860/10000 [2:00:08<55:54,  1.57s/it]
#
# Grid search:  79%|███████▊  | 7862/10000 [2:00:10<49:58,  1.40s/it]
#
# Grid search:  79%|███████▊  | 7863/10000 [2:00:12<52:01,  1.46s/it]
#
# Grid search:  79%|███████▊  | 7864/10000 [2:00:13<53:11,  1.49s/it]
#
# Grid search:  79%|███████▊  | 7865/10000 [2:00:15<53:52,  1.51s/it]
#
# Grid search:  79%|███████▊  | 7866/10000 [2:00:16<54:41,  1.54s/it]
#
# Grid search:  79%|███████▊  | 7867/10000 [2:00:18<55:35,  1.56s/it]
#
# Grid search:  79%|███████▊  | 7868/10000 [2:00:19<55:51,  1.57s/it]
#
# Grid search:  79%|███████▊  | 7869/10000 [2:00:21<55:56,  1.57s/it]
#
# Grid search:  79%|███████▊  | 7870/10000 [2:00:23<55:45,  1.57s/it]
#
# Grid search:  79%|███████▊  | 7872/10000 [2:00:25<49:35,  1.40s/it]
#
# Grid search:  79%|███████▊  | 7873/10000 [2:00:26<50:47,  1.43s/it]
#
# Grid search:  79%|███████▊  | 7874/10000 [2:00:28<51:21,  1.45s/it]
#
# Grid search:  79%|███████▉  | 7875/10000 [2:00:29<52:38,  1.49s/it]
#
# Grid search:  79%|███████▉  | 7876/10000 [2:00:31<53:22,  1.51s/it]
#
# Grid search:  79%|███████▉  | 7877/10000 [2:00:32<54:17,  1.53s/it]
#
# Grid search:  79%|███████▉  | 7878/10000 [2:00:34<54:47,  1.55s/it]
#
# Grid search:  79%|███████▉  | 7879/10000 [2:00:36<54:57,  1.55s/it]
#
# Grid search:  79%|███████▉  | 7880/10000 [2:00:37<55:10,  1.56s/it]
#
# Grid search:  79%|███████▉  | 7882/10000 [2:00:39<50:36,  1.43s/it]
#
# Grid search:  79%|███████▉  | 7883/10000 [2:00:41<51:37,  1.46s/it]
#
# Grid search:  79%|███████▉  | 7884/10000 [2:00:42<52:13,  1.48s/it]
#
# Grid search:  79%|███████▉  | 7885/10000 [2:00:44<52:14,  1.48s/it]
#
# Grid search:  79%|███████▉  | 7886/10000 [2:00:45<52:29,  1.49s/it]
#
# Grid search:  79%|███████▉  | 7887/10000 [2:00:47<52:44,  1.50s/it]
#
# Grid search:  79%|███████▉  | 7888/10000 [2:00:48<52:36,  1.49s/it]
#
# Grid search:  79%|███████▉  | 7889/10000 [2:00:50<52:25,  1.49s/it]
#
# Grid search:  79%|███████▉  | 7890/10000 [2:00:51<52:36,  1.50s/it]
#
# Grid search:  79%|███████▉  | 7892/10000 [2:00:53<47:05,  1.34s/it]
#
# Grid search:  79%|███████▉  | 7893/10000 [2:00:55<48:27,  1.38s/it]
#
# Grid search:  79%|███████▉  | 7894/10000 [2:00:56<49:33,  1.41s/it]
#
# Grid search:  79%|███████▉  | 7895/10000 [2:00:58<50:11,  1.43s/it]
#
# Grid search:  79%|███████▉  | 7896/10000 [2:00:59<50:38,  1.44s/it]
#
# Grid search:  79%|███████▉  | 7897/10000 [2:01:01<51:30,  1.47s/it]
#
# Grid search:  79%|███████▉  | 7898/10000 [2:01:02<52:02,  1.49s/it]
#
# Grid search:  79%|███████▉  | 7899/10000 [2:01:04<52:22,  1.50s/it]
#
# Grid search:  79%|███████▉  | 7900/10000 [2:01:05<52:37,  1.50s/it]
#
# Grid search:  79%|███████▉  | 7902/10000 [2:01:08<49:12,  1.41s/it]
#
# Grid search:  79%|███████▉  | 7903/10000 [2:01:09<51:53,  1.48s/it]
#
# Grid search:  79%|███████▉  | 7904/10000 [2:01:11<52:24,  1.50s/it]
#
# Grid search:  79%|███████▉  | 7905/10000 [2:01:12<52:20,  1.50s/it]
#
# Grid search:  79%|███████▉  | 7906/10000 [2:01:14<52:38,  1.51s/it]
#
# Grid search:  79%|███████▉  | 7907/10000 [2:01:15<52:45,  1.51s/it]
#
# Grid search:  79%|███████▉  | 7908/10000 [2:01:17<52:55,  1.52s/it]
#
# Grid search:  79%|███████▉  | 7909/10000 [2:01:19<52:54,  1.52s/it]
#
# Grid search:  79%|███████▉  | 7910/10000 [2:01:20<52:55,  1.52s/it]
#
# Grid search:  79%|███████▉  | 7912/10000 [2:01:22<47:36,  1.37s/it]
#
# Grid search:  79%|███████▉  | 7913/10000 [2:01:24<49:17,  1.42s/it]
#
# Grid search:  79%|███████▉  | 7914/10000 [2:01:25<50:45,  1.46s/it]
#
# Grid search:  79%|███████▉  | 7915/10000 [2:01:27<51:32,  1.48s/it]
#
# Grid search:  79%|███████▉  | 7916/10000 [2:01:28<51:48,  1.49s/it]
#
# Grid search:  79%|███████▉  | 7917/10000 [2:01:30<51:58,  1.50s/it]
#
# Grid search:  79%|███████▉  | 7918/10000 [2:01:31<52:39,  1.52s/it]
#
# Grid search:  79%|███████▉  | 7919/10000 [2:01:33<53:10,  1.53s/it]
#
# Grid search:  79%|███████▉  | 7920/10000 [2:01:34<53:35,  1.55s/it]
#
# Grid search:  79%|███████▉  | 7922/10000 [2:01:36<48:05,  1.39s/it]
#
# Grid search:  79%|███████▉  | 7923/10000 [2:01:38<49:48,  1.44s/it]
#
# Grid search:  79%|███████▉  | 7924/10000 [2:01:40<50:55,  1.47s/it]
#
# Grid search:  79%|███████▉  | 7925/10000 [2:01:41<52:43,  1.52s/it]
#
# Grid search:  79%|███████▉  | 7926/10000 [2:01:43<53:20,  1.54s/it]
#
# Grid search:  79%|███████▉  | 7927/10000 [2:01:44<53:29,  1.55s/it]
#
# Grid search:  79%|███████▉  | 7928/10000 [2:01:46<53:40,  1.55s/it]
#
# Grid search:  79%|███████▉  | 7929/10000 [2:01:48<53:43,  1.56s/it]
#
# Grid search:  79%|███████▉  | 7930/10000 [2:01:49<53:39,  1.56s/it]
#
# Grid search:  79%|███████▉  | 7932/10000 [2:01:51<47:59,  1.39s/it]
#
# Grid search:  79%|███████▉  | 7933/10000 [2:01:53<49:40,  1.44s/it]
#
# Grid search:  79%|███████▉  | 7934/10000 [2:01:54<51:06,  1.48s/it]
#
# Grid search:  79%|███████▉  | 7935/10000 [2:01:56<52:22,  1.52s/it]
#
# Grid search:  79%|███████▉  | 7936/10000 [2:01:57<53:48,  1.56s/it]
#
# Grid search:  79%|███████▉  | 7937/10000 [2:01:59<55:04,  1.60s/it]
#
# Grid search:  79%|███████▉  | 7938/10000 [2:02:01<55:48,  1.62s/it]
#
# Grid search:  79%|███████▉  | 7939/10000 [2:02:03<56:18,  1.64s/it]
#
# Grid search:  79%|███████▉  | 7940/10000 [2:02:04<56:27,  1.64s/it]
#
# Grid search:  79%|███████▉  | 7942/10000 [2:02:06<50:17,  1.47s/it]
#
# Grid search:  79%|███████▉  | 7943/10000 [2:02:08<51:16,  1.50s/it]
#
# Grid search:  79%|███████▉  | 7944/10000 [2:02:09<51:51,  1.51s/it]
#
# Grid search:  79%|███████▉  | 7945/10000 [2:02:11<52:16,  1.53s/it]
#
# Grid search:  79%|███████▉  | 7946/10000 [2:02:12<52:01,  1.52s/it]
#
# Grid search:  79%|███████▉  | 7947/10000 [2:02:14<53:11,  1.55s/it]
#
# Grid search:  79%|███████▉  | 7948/10000 [2:02:16<53:27,  1.56s/it]
#
# Grid search:  79%|███████▉  | 7949/10000 [2:02:17<53:38,  1.57s/it]
#
# Grid search:  80%|███████▉  | 7950/10000 [2:02:19<53:47,  1.57s/it]
#
# Grid search:  80%|███████▉  | 7952/10000 [2:02:21<48:20,  1.42s/it]
#
# Grid search:  80%|███████▉  | 7953/10000 [2:02:23<49:57,  1.46s/it]
#
# Grid search:  80%|███████▉  | 7954/10000 [2:02:24<51:06,  1.50s/it]
#
# Grid search:  80%|███████▉  | 7955/10000 [2:02:26<51:53,  1.52s/it]
#
# Grid search:  80%|███████▉  | 7956/10000 [2:02:27<52:25,  1.54s/it]
#
# Grid search:  80%|███████▉  | 7957/10000 [2:02:29<52:51,  1.55s/it]
#
# Grid search:  80%|███████▉  | 7958/10000 [2:02:30<53:10,  1.56s/it]
#
# Grid search:  80%|███████▉  | 7959/10000 [2:02:32<53:42,  1.58s/it]
#
# Grid search:  80%|███████▉  | 7960/10000 [2:02:34<53:47,  1.58s/it]
#
# Grid search:  80%|███████▉  | 7962/10000 [2:02:36<48:10,  1.42s/it]
#
# Grid search:  80%|███████▉  | 7963/10000 [2:02:37<49:52,  1.47s/it]
#
# Grid search:  80%|███████▉  | 7964/10000 [2:02:39<50:55,  1.50s/it]
#
# Grid search:  80%|███████▉  | 7965/10000 [2:02:40<51:39,  1.52s/it]
#
# Grid search:  80%|███████▉  | 7966/10000 [2:02:42<52:47,  1.56s/it]
#
# Grid search:  80%|███████▉  | 7967/10000 [2:02:44<53:05,  1.57s/it]
#
# Grid search:  80%|███████▉  | 7968/10000 [2:02:45<53:16,  1.57s/it]
#
# Grid search:  80%|███████▉  | 7969/10000 [2:02:47<54:07,  1.60s/it]
#
# Grid search:  80%|███████▉  | 7970/10000 [2:02:48<53:32,  1.58s/it]
#
# Grid search:  80%|███████▉  | 7972/10000 [2:02:50<47:43,  1.41s/it]
#
# Grid search:  80%|███████▉  | 7973/10000 [2:02:52<49:14,  1.46s/it]
#
# Grid search:  80%|███████▉  | 7974/10000 [2:02:54<50:21,  1.49s/it]
#
# Grid search:  80%|███████▉  | 7975/10000 [2:02:55<51:01,  1.51s/it]
#
# Grid search:  80%|███████▉  | 7976/10000 [2:02:57<51:34,  1.53s/it]
#
# Grid search:  80%|███████▉  | 7977/10000 [2:02:58<51:49,  1.54s/it]
#
# Grid search:  80%|███████▉  | 7978/10000 [2:03:00<52:02,  1.54s/it]
#
# Grid search:  80%|███████▉  | 7979/10000 [2:03:01<52:22,  1.55s/it]
#
# Grid search:  80%|███████▉  | 7980/10000 [2:03:03<52:51,  1.57s/it]
#
# Grid search:  80%|███████▉  | 7982/10000 [2:03:05<47:19,  1.41s/it]
#
# Grid search:  80%|███████▉  | 7983/10000 [2:03:07<48:45,  1.45s/it]
#
# ...
#
# Grid search:  97%|█████████▋| 9745/10000 [2:48:42<07:25,  1.75s/it]
#
# Grid search:  97%|█████████▋| 9746/10000 [2:48:44<07:26,  1.76s/it]
#
# Grid search:  97%|█████████▋| 9747/10000 [2:48:46<07:25,  1.76s/it]
#
# Grid search:  97%|█████████▋| 9748/10000 [2:48:48<07:21,  1.75s/it]
#
# Grid search:  97%|█████████▋| 9749/10000 [2:48:49<07:18,  1.75s/it]
#
# Grid search:  98%|█████████▊| 9750/10000 [2:48:51<07:17,  1.75s/it]
#
# Grid search:  98%|█████████▊| 9752/10000 [2:48:53<06:26,  1.56s/it]
#
# Grid search:  98%|█████████▊| 9753/10000 [2:48:55<06:41,  1.62s/it]
#
# Grid search:  98%|█████████▊| 9754/10000 [2:48:57<06:48,  1.66s/it]
#
# Grid search:  98%|█████████▊| 9755/10000 [2:48:59<06:51,  1.68s/it]
#
# Grid search:  98%|█████████▊| 9756/10000 [2:49:00<06:53,  1.70s/it]
#
# Grid search:  98%|█████████▊| 9757/10000 [2:49:02<06:57,  1.72s/it]
#
# Grid search:  98%|█████████▊| 9758/10000 [2:49:04<06:57,  1.73s/it]
#
# Grid search:  98%|█████████▊| 9759/10000 [2:49:06<06:58,  1.74s/it]
#
# Grid search:  98%|█████████▊| 9760/10000 [2:49:07<06:58,  1.74s/it]
#
# Grid search:  98%|█████████▊| 9762/10000 [2:49:10<06:08,  1.55s/it]
#
# Grid search:  98%|█████████▊| 9763/10000 [2:49:11<06:22,  1.61s/it]
#
# Grid search:  98%|█████████▊| 9764/10000 [2:49:13<06:31,  1.66s/it]
#
# Grid search:  98%|█████████▊| 9765/10000 [2:49:15<06:35,  1.68s/it]
#
# Grid search:  98%|█████████▊| 9766/10000 [2:49:17<06:37,  1.70s/it]
#
# Grid search:  98%|█████████▊| 9767/10000 [2:49:18<06:38,  1.71s/it]
#
# Grid search:  98%|█████████▊| 9768/10000 [2:49:20<06:36,  1.71s/it]
#
# Grid search:  98%|█████████▊| 9769/10000 [2:49:22<06:46,  1.76s/it]
#
# Grid search:  98%|█████████▊| 9770/10000 [2:49:24<06:47,  1.77s/it]
#
# Grid search:  98%|█████████▊| 9772/10000 [2:49:26<06:02,  1.59s/it]
#
# Grid search:  98%|█████████▊| 9773/10000 [2:49:28<06:10,  1.63s/it]
#
# Grid search:  98%|█████████▊| 9774/10000 [2:49:30<06:18,  1.67s/it]
#
# Grid search:  98%|█████████▊| 9775/10000 [2:49:31<06:22,  1.70s/it]
#
# Grid search:  98%|█████████▊| 9776/10000 [2:49:33<06:23,  1.71s/it]
#
# Grid search:  98%|█████████▊| 9777/10000 [2:49:35<06:25,  1.73s/it]
#
# Grid search:  98%|█████████▊| 9778/10000 [2:49:37<06:23,  1.73s/it]
#
# Grid search:  98%|█████████▊| 9779/10000 [2:49:38<06:20,  1.72s/it]
#
# Grid search:  98%|█████████▊| 9780/10000 [2:49:40<06:18,  1.72s/it]
#
# Grid search:  98%|█████████▊| 9782/10000 [2:49:42<05:34,  1.54s/it]
#
# Grid search:  98%|█████████▊| 9783/10000 [2:49:44<05:47,  1.60s/it]
#
# Grid search:  98%|█████████▊| 9784/10000 [2:49:46<05:56,  1.65s/it]
#
# Grid search:  98%|█████████▊| 9785/10000 [2:49:47<05:58,  1.67s/it]
#
# Grid search:  98%|█████████▊| 9786/10000 [2:49:49<06:01,  1.69s/it]
#
# Grid search:  98%|█████████▊| 9787/10000 [2:49:51<06:03,  1.71s/it]
#
# Grid search:  98%|█████████▊| 9788/10000 [2:49:53<06:05,  1.72s/it]
#
# Grid search:  98%|█████████▊| 9789/10000 [2:49:54<06:03,  1.72s/it]
#
# Grid search:  98%|█████████▊| 9790/10000 [2:49:56<06:03,  1.73s/it]
#
# Grid search:  98%|█████████▊| 9792/10000 [2:49:58<05:20,  1.54s/it]
#
# Grid search:  98%|█████████▊| 9793/10000 [2:50:00<05:31,  1.60s/it]
#
# Grid search:  98%|█████████▊| 9794/10000 [2:50:02<05:40,  1.65s/it]
#
# Grid search:  98%|█████████▊| 9795/10000 [2:50:04<05:45,  1.68s/it]
#
# Grid search:  98%|█████████▊| 9796/10000 [2:50:06<05:54,  1.74s/it]
#
# Grid search:  98%|█████████▊| 9797/10000 [2:50:07<05:55,  1.75s/it]
#
# Grid search:  98%|█████████▊| 9798/10000 [2:50:09<05:52,  1.74s/it]
#
# Grid search:  98%|█████████▊| 9799/10000 [2:50:11<05:48,  1.74s/it]
#
# Grid search:  98%|█████████▊| 9800/10000 [2:50:13<05:48,  1.74s/it]
#
# Grid search:  98%|█████████▊| 9802/10000 [2:50:15<05:19,  1.61s/it]
#
# Grid search:  98%|█████████▊| 9803/10000 [2:50:17<05:24,  1.65s/it]
#
# Grid search:  98%|█████████▊| 9804/10000 [2:50:19<05:29,  1.68s/it]
#
# Grid search:  98%|█████████▊| 9805/10000 [2:50:20<05:33,  1.71s/it]
#
# Grid search:  98%|█████████▊| 9806/10000 [2:50:22<05:34,  1.72s/it]
#
# Grid search:  98%|█████████▊| 9807/10000 [2:50:24<05:34,  1.73s/it]
#
# Grid search:  98%|█████████▊| 9808/10000 [2:50:26<05:33,  1.74s/it]
#
# Grid search:  98%|█████████▊| 9809/10000 [2:50:27<05:31,  1.74s/it]
#
# Grid search:  98%|█████████▊| 9810/10000 [2:50:29<05:30,  1.74s/it]
#
# Grid search:  98%|█████████▊| 9812/10000 [2:50:31<04:53,  1.56s/it]
#
# Grid search:  98%|█████████▊| 9813/10000 [2:50:33<05:02,  1.62s/it]
#
# Grid search:  98%|█████████▊| 9814/10000 [2:50:35<05:10,  1.67s/it]
#
# Grid search:  98%|█████████▊| 9815/10000 [2:50:37<05:13,  1.70s/it]
#
# Grid search:  98%|█████████▊| 9816/10000 [2:50:38<05:14,  1.71s/it]
#
# Grid search:  98%|█████████▊| 9817/10000 [2:50:40<05:14,  1.72s/it]
#
# Grid search:  98%|█████████▊| 9818/10000 [2:50:42<05:14,  1.73s/it]
#
# Grid search:  98%|█████████▊| 9819/10000 [2:50:44<05:20,  1.77s/it]
#
# Grid search:  98%|█████████▊| 9820/10000 [2:50:46<05:21,  1.78s/it]
#
# Grid search:  98%|█████████▊| 9822/10000 [2:50:48<04:41,  1.58s/it]
#
# Grid search:  98%|█████████▊| 9823/10000 [2:50:50<04:47,  1.62s/it]
#
# Grid search:  98%|█████████▊| 9824/10000 [2:50:51<04:54,  1.67s/it]
#
# Grid search:  98%|█████████▊| 9825/10000 [2:50:53<04:57,  1.70s/it]
#
# Grid search:  98%|█████████▊| 9826/10000 [2:50:55<04:58,  1.72s/it]
#
# Grid search:  98%|█████████▊| 9827/10000 [2:50:57<04:59,  1.73s/it]
#
# Grid search:  98%|█████████▊| 9828/10000 [2:50:58<04:58,  1.73s/it]
#
# Grid search:  98%|█████████▊| 9829/10000 [2:51:00<04:55,  1.73s/it]
#
# Grid search:  98%|█████████▊| 9830/10000 [2:51:02<04:54,  1.73s/it]
#
# Grid search:  98%|█████████▊| 9832/10000 [2:51:04<04:20,  1.55s/it]
#
# Grid search:  98%|█████████▊| 9833/10000 [2:51:06<04:29,  1.61s/it]
#
# Grid search:  98%|█████████▊| 9834/10000 [2:51:08<04:34,  1.65s/it]
#
# Grid search:  98%|█████████▊| 9835/10000 [2:51:09<04:36,  1.67s/it]
#
# Grid search:  98%|█████████▊| 9836/10000 [2:51:11<04:37,  1.69s/it]
#
# Grid search:  98%|█████████▊| 9837/10000 [2:51:13<04:39,  1.71s/it]
#
# Grid search:  98%|█████████▊| 9838/10000 [2:51:15<04:38,  1.72s/it]
#
# Grid search:  98%|█████████▊| 9839/10000 [2:51:16<04:38,  1.73s/it]
#
# Grid search:  98%|█████████▊| 9840/10000 [2:51:18<04:36,  1.73s/it]
#
# Grid search:  98%|█████████▊| 9842/10000 [2:51:20<04:04,  1.54s/it]
#
# Grid search:  98%|█████████▊| 9843/10000 [2:51:22<04:11,  1.60s/it]
#
# Grid search:  98%|█████████▊| 9844/10000 [2:51:24<04:18,  1.65s/it]
#
# Grid search:  98%|█████████▊| 9845/10000 [2:51:26<04:21,  1.69s/it]
#
# Grid search:  98%|█████████▊| 9846/10000 [2:51:27<04:29,  1.75s/it]
#
# Grid search:  98%|█████████▊| 9847/10000 [2:51:29<04:26,  1.74s/it]
#
# Grid search:  98%|█████████▊| 9848/10000 [2:51:31<04:26,  1.75s/it]
#
# Grid search:  98%|█████████▊| 9849/10000 [2:51:33<04:20,  1.72s/it]
#
# Grid search:  98%|█████████▊| 9850/10000 [2:51:34<04:20,  1.73s/it]
#
# Grid search:  99%|█████████▊| 9852/10000 [2:51:37<03:49,  1.55s/it]
#
# Grid search:  99%|█████████▊| 9853/10000 [2:51:38<03:57,  1.61s/it]
#
# Grid search:  99%|█████████▊| 9854/10000 [2:51:40<04:02,  1.66s/it]
#
# Grid search:  99%|█████████▊| 9855/10000 [2:51:42<04:03,  1.68s/it]
#
# Grid search:  99%|█████████▊| 9856/10000 [2:51:44<04:06,  1.71s/it]
#
# Grid search:  99%|█████████▊| 9857/10000 [2:51:45<04:07,  1.73s/it]
#
# Grid search:  99%|█████████▊| 9858/10000 [2:51:47<04:05,  1.73s/it]
#
# Grid search:  99%|█████████▊| 9859/10000 [2:51:49<04:04,  1.74s/it]
#
# Grid search:  99%|█████████▊| 9860/10000 [2:51:51<04:04,  1.74s/it]
#
# Grid search:  99%|█████████▊| 9862/10000 [2:51:53<03:34,  1.56s/it]
#
# Grid search:  99%|█████████▊| 9863/10000 [2:51:55<03:40,  1.61s/it]
#
# Grid search:  99%|█████████▊| 9864/10000 [2:51:56<03:44,  1.65s/it]
#
# Grid search:  99%|█████████▊| 9865/10000 [2:51:58<03:46,  1.68s/it]
#
# Grid search:  99%|█████████▊| 9866/10000 [2:52:00<03:47,  1.70s/it]
#
# Grid search:  99%|█████████▊| 9867/10000 [2:52:02<03:47,  1.71s/it]
#
# Grid search:  99%|█████████▊| 9868/10000 [2:52:03<03:47,  1.72s/it]
#
# Grid search:  99%|█████████▊| 9869/10000 [2:52:05<03:46,  1.73s/it]
#
# Grid search:  99%|█████████▊| 9870/10000 [2:52:07<03:50,  1.77s/it]
#
# Grid search:  99%|█████████▊| 9872/10000 [2:52:09<03:21,  1.57s/it]
#
# Grid search:  99%|█████████▊| 9873/10000 [2:52:11<03:26,  1.63s/it]
#
# Grid search:  99%|█████████▊| 9874/10000 [2:52:13<03:30,  1.67s/it]
#
# Grid search:  99%|█████████▉| 9875/10000 [2:52:14<03:30,  1.69s/it]
#
# Grid search:  99%|█████████▉| 9876/10000 [2:52:16<03:31,  1.70s/it]
#
# Grid search:  99%|█████████▉| 9877/10000 [2:52:18<03:29,  1.71s/it]
#
# Grid search:  99%|█████████▉| 9878/10000 [2:52:20<03:28,  1.71s/it]
#
# Grid search:  99%|█████████▉| 9879/10000 [2:52:21<03:28,  1.72s/it]
#
# Grid search:  99%|█████████▉| 9880/10000 [2:52:23<03:28,  1.73s/it]
#
# Grid search:  99%|█████████▉| 9882/10000 [2:52:25<03:03,  1.55s/it]
#
# Grid search:  99%|█████████▉| 9883/10000 [2:52:27<03:08,  1.61s/it]
#
# Grid search:  99%|█████████▉| 9884/10000 [2:52:29<03:12,  1.66s/it]
#
# Grid search:  99%|█████████▉| 9885/10000 [2:52:31<03:13,  1.68s/it]
#
# Grid search:  99%|█████████▉| 9886/10000 [2:52:32<03:15,  1.71s/it]
#
# Grid search:  99%|█████████▉| 9887/10000 [2:52:34<03:14,  1.72s/it]
#
# Grid search:  99%|█████████▉| 9888/10000 [2:52:36<03:13,  1.73s/it]
#
# Grid search:  99%|█████████▉| 9889/10000 [2:52:38<03:13,  1.74s/it]
#
# Grid search:  99%|█████████▉| 9890/10000 [2:52:39<03:12,  1.75s/it]
#
# Grid search:  99%|█████████▉| 9892/10000 [2:52:42<02:48,  1.56s/it]
#
# Grid search:  99%|█████████▉| 9893/10000 [2:52:43<02:53,  1.62s/it]
#
# Grid search:  99%|█████████▉| 9894/10000 [2:52:45<02:56,  1.66s/it]
#
# Grid search:  99%|█████████▉| 9895/10000 [2:52:47<02:56,  1.68s/it]
#
# Grid search:  99%|█████████▉| 9896/10000 [2:52:49<03:01,  1.75s/it]
#
# Grid search:  99%|█████████▉| 9897/10000 [2:52:51<03:00,  1.76s/it]
#
# Grid search:  99%|█████████▉| 9898/10000 [2:52:52<02:58,  1.75s/it]
#
# Grid search:  99%|█████████▉| 9899/10000 [2:52:54<02:56,  1.75s/it]
#
# Grid search:  99%|█████████▉| 9900/10000 [2:52:56<02:54,  1.75s/it]
#
# Grid search:  99%|█████████▉| 9902/10000 [2:52:58<02:38,  1.62s/it]
#
# Grid search:  99%|█████████▉| 9903/10000 [2:53:00<02:40,  1.65s/it]
#
# Grid search:  99%|█████████▉| 9904/10000 [2:53:02<02:41,  1.68s/it]
#
# Grid search:  99%|█████████▉| 9905/10000 [2:53:04<02:41,  1.70s/it]
#
# Grid search:  99%|█████████▉| 9906/10000 [2:53:05<02:40,  1.71s/it]
#
# Grid search:  99%|█████████▉| 9907/10000 [2:53:07<02:40,  1.72s/it]
#
# Grid search:  99%|█████████▉| 9908/10000 [2:53:09<02:38,  1.73s/it]
#
# Grid search:  99%|█████████▉| 9909/10000 [2:53:11<02:38,  1.74s/it]
#
# Grid search:  99%|█████████▉| 9910/10000 [2:53:12<02:36,  1.74s/it]
#
# Grid search:  99%|█████████▉| 9912/10000 [2:53:15<02:16,  1.55s/it]
#
# Grid search:  99%|█████████▉| 9913/10000 [2:53:16<02:19,  1.60s/it]
#
# Grid search:  99%|█████████▉| 9914/10000 [2:53:18<02:20,  1.64s/it]
#
# Grid search:  99%|█████████▉| 9915/10000 [2:53:20<02:21,  1.66s/it]
#
# Grid search:  99%|█████████▉| 9916/10000 [2:53:22<02:21,  1.69s/it]
#
# Grid search:  99%|█████████▉| 9917/10000 [2:53:23<02:21,  1.70s/it]
#
# Grid search:  99%|█████████▉| 9918/10000 [2:53:25<02:20,  1.72s/it]
#
# Grid search:  99%|█████████▉| 9919/10000 [2:53:27<02:19,  1.72s/it]
#
# Grid search:  99%|█████████▉| 9920/10000 [2:53:29<02:19,  1.75s/it]
#
# Grid search:  99%|█████████▉| 9922/10000 [2:53:31<02:01,  1.55s/it]
#
# Grid search:  99%|█████████▉| 9923/10000 [2:53:32<02:03,  1.61s/it]
#
# Grid search:  99%|█████████▉| 9924/10000 [2:53:34<02:05,  1.65s/it]
#
# Grid search:  99%|█████████▉| 9925/10000 [2:53:36<02:05,  1.67s/it]
#
# Grid search:  99%|█████████▉| 9926/10000 [2:53:38<02:05,  1.69s/it]
#
# Grid search:  99%|█████████▉| 9927/10000 [2:53:39<02:04,  1.71s/it]
#
# Grid search:  99%|█████████▉| 9928/10000 [2:53:41<02:06,  1.76s/it]
#
# Grid search:  99%|█████████▉| 9929/10000 [2:53:43<02:14,  1.89s/it]
#
# Grid search:  99%|█████████▉| 9930/10000 [2:53:45<02:10,  1.86s/it]
#
# Grid search:  99%|█████████▉| 9932/10000 [2:53:47<01:50,  1.63s/it]
#
# Grid search:  99%|█████████▉| 9933/10000 [2:53:49<01:51,  1.67s/it]
#
# Grid search:  99%|█████████▉| 9934/10000 [2:53:51<01:53,  1.71s/it]
#
# Grid search:  99%|█████████▉| 9935/10000 [2:53:53<01:52,  1.73s/it]
#
# Grid search:  99%|█████████▉| 9936/10000 [2:53:55<01:50,  1.73s/it]
#
# Grid search:  99%|█████████▉| 9937/10000 [2:53:56<01:50,  1.75s/it]
#
# Grid search:  99%|█████████▉| 9938/10000 [2:53:58<01:47,  1.74s/it]
#
# Grid search:  99%|█████████▉| 9939/10000 [2:54:00<01:45,  1.73s/it]
#
# Grid search:  99%|█████████▉| 9940/10000 [2:54:02<01:44,  1.74s/it]
#
# Grid search:  99%|█████████▉| 9942/10000 [2:54:04<01:29,  1.55s/it]
#
# Grid search:  99%|█████████▉| 9943/10000 [2:54:05<01:31,  1.60s/it]
#
# Grid search:  99%|█████████▉| 9944/10000 [2:54:07<01:32,  1.65s/it]
#
# Grid search:  99%|█████████▉| 9945/10000 [2:54:09<01:31,  1.67s/it]
#
# Grid search:  99%|█████████▉| 9946/10000 [2:54:11<01:33,  1.72s/it]
#
# Grid search:  99%|█████████▉| 9947/10000 [2:54:13<01:31,  1.73s/it]
#
# Grid search:  99%|█████████▉| 9948/10000 [2:54:14<01:30,  1.73s/it]
#
# Grid search:  99%|█████████▉| 9949/10000 [2:54:16<01:28,  1.74s/it]
#
# Grid search: 100%|█████████▉| 9950/10000 [2:54:18<01:27,  1.74s/it]
#
# Grid search: 100%|█████████▉| 9952/10000 [2:54:20<01:14,  1.55s/it]
#
# Grid search: 100%|█████████▉| 9953/10000 [2:54:22<01:15,  1.61s/it]
#
# Grid search: 100%|█████████▉| 9954/10000 [2:54:23<01:16,  1.66s/it]
#
# Grid search: 100%|█████████▉| 9955/10000 [2:54:25<01:15,  1.69s/it]
#
# Grid search: 100%|█████████▉| 9956/10000 [2:54:27<01:14,  1.70s/it]
#
# Grid search: 100%|█████████▉| 9957/10000 [2:54:29<01:13,  1.70s/it]
#
# Grid search: 100%|█████████▉| 9958/10000 [2:54:30<01:11,  1.71s/it]
#
# Grid search: 100%|█████████▉| 9959/10000 [2:54:32<01:10,  1.73s/it]
#
# Grid search: 100%|█████████▉| 9960/10000 [2:54:34<01:09,  1.74s/it]
#
# Grid search: 100%|█████████▉| 9962/10000 [2:54:36<00:58,  1.55s/it]
#
# Grid search: 100%|█████████▉| 9963/10000 [2:54:38<00:59,  1.61s/it]
#
# Grid search: 100%|█████████▉| 9964/10000 [2:54:40<00:59,  1.66s/it]
#
# Grid search: 100%|█████████▉| 9965/10000 [2:54:41<00:58,  1.68s/it]
#
# Grid search: 100%|█████████▉| 9966/10000 [2:54:43<00:58,  1.71s/it]
#
# Grid search: 100%|█████████▉| 9967/10000 [2:54:45<00:56,  1.72s/it]
#
# Grid search: 100%|█████████▉| 9968/10000 [2:54:47<00:54,  1.71s/it]
#
# Grid search: 100%|█████████▉| 9969/10000 [2:54:48<00:53,  1.72s/it]
#
# Grid search: 100%|█████████▉| 9970/10000 [2:54:50<00:52,  1.75s/it]
#
# Grid search: 100%|█████████▉| 9972/10000 [2:54:52<00:43,  1.56s/it]
#
# Grid search: 100%|█████████▉| 9973/10000 [2:54:54<00:43,  1.62s/it]
#
# Grid search: 100%|█████████▉| 9974/10000 [2:54:56<00:42,  1.65s/it]
#
# Grid search: 100%|█████████▉| 9975/10000 [2:54:58<00:42,  1.69s/it]
#
# Grid search: 100%|█████████▉| 9976/10000 [2:54:59<00:40,  1.70s/it]
#
# Grid search: 100%|█████████▉| 9977/10000 [2:55:01<00:39,  1.71s/it]
#
# Grid search: 100%|█████████▉| 9978/10000 [2:55:03<00:37,  1.72s/it]
#
# Grid search: 100%|█████████▉| 9979/10000 [2:55:05<00:36,  1.73s/it]
#
# Grid search: 100%|█████████▉| 9980/10000 [2:55:06<00:34,  1.74s/it]
#
# Grid search: 100%|█████████▉| 9982/10000 [2:55:09<00:27,  1.55s/it]
#
# Grid search: 100%|█████████▉| 9983/10000 [2:55:10<00:27,  1.61s/it]
#
# Grid search: 100%|█████████▉| 9984/10000 [2:55:12<00:26,  1.66s/it]
#
# Grid search: 100%|█████████▉| 9985/10000 [2:55:14<00:25,  1.68s/it]
#
# Grid search: 100%|█████████▉| 9986/10000 [2:55:16<00:23,  1.70s/it]
#
# Grid search: 100%|█████████▉| 9987/10000 [2:55:17<00:22,  1.71s/it]
#
# Grid search: 100%|█████████▉| 9988/10000 [2:55:19<00:20,  1.71s/it]
#
# Grid search: 100%|█████████▉| 9989/10000 [2:55:21<00:18,  1.72s/it]
#
# Grid search: 100%|█████████▉| 9990/10000 [2:55:23<00:17,  1.72s/it]
#
# Grid search: 100%|█████████▉| 9992/10000 [2:55:25<00:12,  1.54s/it]
#
# Grid search: 100%|█████████▉| 9993/10000 [2:55:26<00:11,  1.59s/it]
#
# Grid search: 100%|█████████▉| 9994/10000 [2:55:28<00:09,  1.62s/it]
#
# Grid search: 100%|█████████▉| 9995/10000 [2:55:30<00:08,  1.65s/it]
#
# Grid search: 100%|█████████▉| 9996/10000 [2:55:32<00:06,  1.71s/it]
#
# Grid search: 100%|█████████▉| 9997/10000 [2:55:33<00:05,  1.72s/it]
#
# Grid search: 100%|█████████▉| 9998/10000 [2:55:35<00:03,  1.73s/it]
#
# Grid search: 100%|█████████▉| 9999/10000 [2:55:37<00:01,  1.74s/it]
#
# Grid search: 100%|██████████| 10000/10000 [2:55:39<00:00,  1.05s/it]

# %%
clf.set_hyperparameters(s=best_s, l=best_l, p=best_p, a=best_a)
Evaluation.test(clf, X_val_enhanced, y_val, metric='f1-score')
# Out:
# Caching documents:   0%|          | 0/1125 [00:00<?, ?it/s]
#
# Caching documents:  25%|██▍       | 277/1125 [00:00<00:00, 1264.80it/s]
#
# Caching documents:  34%|███▍      | 388/1125 [00:00<00:00, 940.97it/s]
#
# Caching documents:  62%|██████▏   | 701/1125 [00:00<00:00, 1040.80it/s]
#
#
#
# Classification: 100%|██████████| 1125/1125 [00:00<00:00, 14954.64it/s]
#                        precision    recall  f1-score   support
#
#               general       0.66      0.81      0.73       529
#             usability       0.40      0.72      0.51        76
# operation_performance       0.65      0.70      0.67       139
#               quality       0.69      0.72      0.70       364
#           portability       0.48      0.71      0.57        14
#       design_features       0.48      0.77      0.59       106
#         style_options       0.38      0.62      0.47        45
#                 price       0.34      0.83      0.48        52
#         miscellaneous       0.47      0.39      0.42        75
#                prices       0.21      0.80      0.33        45
#          connectivity       0.48      0.45      0.47        22
#
#             micro avg       0.55      0.74      0.63      1467
#             macro avg       0.47      0.69      0.54      1467
#          weighted avg       0.59      0.74      0.65      1467
#           samples avg       0.62      0.76      0.65      1467
#
#
#  Exact Match Ratio: 0.350
#  Hamming Loss: 0.102
# [ updating evaluations cache ]
# 0.54184454803254

# %%
print("Best s:", best_s, " Best l:", best_l, " Best p:", best_p, " Best a:", best_a)
# Out:
# Best s: 0.8889  Best l: 0.0  Best p: 1.1111  Best a: 0.1111

# %%
clf.set_hyperparameters(s=0.88, l=0, p=1.11, a=0.11)
Evaluation.test(clf, X_val_enhanced, y_val, metric='f1-score')
# Out:
# Classification: 100%|██████████| 1125/1125 [00:00<00:00, 15387.75it/s]
#                        precision    recall  f1-score   support
#
#               general       0.67      0.82      0.74       529
#             usability       0.40      0.72      0.52        76
# operation_performance       0.66      0.68      0.67       139
#               quality       0.68      0.73      0.71       364
#           portability       0.48      0.71      0.57        14
#       design_features       0.48      0.77      0.59       106
#         style_options       0.33      0.62      0.43        45
#                 price       0.35      0.83      0.49        52
#         miscellaneous       0.47      0.39      0.42        75
#                prices       0.21      0.80      0.33        45
#          connectivity       0.48      0.45      0.47        22
#
#             micro avg       0.55      0.74      0.63      1467
#             macro avg       0.47      0.69      0.54      1467
#          weighted avg       0.59      0.74      0.65      1467
#           samples avg       0.62      0.76      0.65      1467
#
#
#  Exact Match Ratio: 0.351
#  Hamming Loss: 0.102
# [ updating evaluations cache ]
# 0.5399012451456714
